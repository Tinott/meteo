# %% [markdown]
# ---
# ## 1. Librairies et constantes

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import xarray as xr
import gc
import os
from scipy.optimize import curve_fit

plt.rcParams.update({'figure.dpi': 100, 'font.size': 11})

Rd      = 287.05
Rv      = 461.5
EPSILON = Rd / Rv

DIR_3D = '3D'
DIR_2D = '2D'
DIR_1D = '1D'

def path3d(var):
    return os.path.join(DIR_3D, f'MESONH_RCE_large300_3D_{var}.nc')

def path2d(var):
    return os.path.join(DIR_2D, f'MESONH_RCE_large300_2D_{var}.nc')

def path1d(var):
    return os.path.join(DIR_1D, f'MESONH_RCE_large300_1D_{var}.nc')

BLOC = 2
dx   = 2000.0
dy   = 2000.0

print('Prêt.')
# Out:
# Prêt.

# %% [markdown]
# ---
# ## 2. Dimensions de la grille

# %%
_ds = xr.open_dataset(path3d('ua'))
_da = _ds['ua']

dim_t = _da.dims[0]
dim_z = _da.dims[1]
dim_y = _da.dims[2]
dim_x = _da.dims[3]

n_t = _da.sizes[dim_t]
n_z = _da.sizes[dim_z]
n_y = _da.sizes[dim_y]
n_x = _da.sizes[dim_x]
times = _da[dim_t].values.copy()

_ds.close()
del _ds, _da
gc.collect()

# altitude depuis le fichier 1D (valeurs en mètres)
_ds1 = xr.open_dataset(path1d('ua_avg'))
alt  = _ds1.altitude.values.copy()
_ds1.close()
del _ds1
gc.collect()

t_stat   = int(2 * n_t / 3)
idx_stat = slice(t_stat, None)
n_stat   = n_t - t_stat
time_days = times.astype('float64') // 4

print(f'Grille : {n_t} t  x  {n_z} z  x  {n_y} y  x  {n_x} x')
print(f'Altitude : {alt[0]:.0f} — {alt[-1]:.0f} m')
print(f'État stationnaire : t={t_stat} → {n_t-1}  ({n_stat} pas)')
# Out:
# Grille : 100 t  x  74 z  x  128 y  x  2000 x
# Altitude : 0 — 32500 m
# État stationnaire : t=66 → 99  (34 pas)

# %% [markdown]
# ---
# ## 3. Masques humide / sec (PRW)

# %%
ds_prw   = xr.open_dataset(path2d('prw'))
prw_all  = ds_prw['prw'].load()
ds_prw.close()

prw_mean  = prw_all.isel({dim_t: idx_stat}).mean(dim=dim_t)
PRW_SEUIL = float(np.median(prw_all.values.ravel()))

mh = (prw_mean.values > PRW_SEUIL)
ms = ~mh

del prw_all
gc.collect()

print(f'Seuil PRW : {PRW_SEUIL:.1f} kg/m²')
print(f'Humide : {mh.mean()*100:.1f}%   Sec : {ms.mean()*100:.1f}%')
# Out:
# Seuil PRW : 30.4 kg/m²
# Humide : 42.3%   Sec : 57.7%

# %% [markdown]
# ---
# ## 4. Profil ρ₀

# %%
rho0_sum = np.zeros(n_z)
n_rho    = 0

ds_ta  = xr.open_dataset(path3d('ta'))
ds_pa  = xr.open_dataset(path3d('pa'))
ds_hus = xr.open_dataset(path3d('hus'))

for t0 in range(t_stat, n_t, BLOC):
    t1     = min(t0 + BLOC, n_t)
    sl     = {dim_t: slice(t0, t1)}
    T_blk  = ds_ta['ta'].isel(sl).values
    p_blk  = ds_pa['pa'].isel(sl).values
    qv_blk = ds_hus['hus'].isel(sl).values
    Tv_blk = T_blk * (1.0 + qv_blk / EPSILON) / (1.0 + qv_blk)
    rho_blk = p_blk / (Rd * Tv_blk)
    rho0_sum += rho_blk.mean(axis=(0, 2, 3)) * (t1 - t0)
    n_rho    += (t1 - t0)
    del T_blk, p_blk, qv_blk, Tv_blk, rho_blk
    gc.collect()

ds_ta.close() ; ds_pa.close() ; ds_hus.close()
del ds_ta, ds_pa, ds_hus
gc.collect()

rho0 = rho0_sum / n_rho

print(f'ρ₀ calculé sur {n_rho} pas de temps.')
print(f'  Surface : {rho0[0]:.3f} kg/m³')
print(f'  ~10 km  : {rho0[np.argmin(np.abs(alt-10000))]:.3f} kg/m³')
# Out:
# ρ₀ calculé sur 34 pas de temps.
#   Surface : 1.183 kg/m³
#   ~10 km  : 0.410 kg/m³

# %% [markdown]
# # §17 — Paramétrisation polynome flux de reynolds — Notebook autonome
# Recalcule tout depuis zéro : imports, dimensions, ρ₀, masques humide/sec, flux de Reynolds par région, puis fit analytique.

# %% [markdown]
# ---
# ## 5. Fonction utilitaire

# %%
def tendance(flux_profil):
    """Force de Reynolds : -1/rho0 · d(rho0 <u'w'>) / dz"""
    return -np.gradient(flux_profil, alt) / rho0

# %% [markdown]
# ---
# ## 6. Calcul des flux de Reynolds par région (§16)
#
# Calcule `flux_loc_h/s` (anomalies intra-région) et `flux_glob_h/s` (anomalies domaine entier)
# niveau par niveau pour économiser la RAM.

# %%
flux_loc_h  = np.zeros(n_z)
flux_loc_s  = np.zeros(n_z)
flux_glob_h = np.zeros(n_z)
flux_glob_s = np.zeros(n_z)

ds_u = xr.open_dataset(path3d('ua'))
ds_w = xr.open_dataset(path3d('wa'))

for iz in range(n_z):

    acc_loc_h  = 0.0 ; acc_loc_s  = 0.0
    acc_glob_h = 0.0 ; acc_glob_s = 0.0
    n = 0

    for it in range(t_stat, n_t):

        u_2d = ds_u['ua'].isel({dim_t: it, dim_z: iz}).values
        w_2d = ds_w['wa'].isel({dim_t: it, dim_z: iz}).values

        # anomalies locales (intra-région)
        u_h = u_2d[mh] ; u_s = u_2d[ms]
        w_h = w_2d[mh] ; w_s = w_2d[ms]
        acc_loc_h += ((u_h - u_h.mean()) * (w_h - w_h.mean())).mean()
        acc_loc_s += ((u_s - u_s.mean()) * (w_s - w_s.mean())).mean()

        # anomalies globales (domaine entier)
        u_p = u_2d - u_2d.mean()
        w_p = w_2d - w_2d.mean()
        acc_glob_h += (u_p * w_p)[mh].mean()
        acc_glob_s += (u_p * w_p)[ms].mean()

        n += 1
        del u_2d, w_2d, u_h, u_s, w_h, w_s, u_p, w_p
        gc.collect()

    flux_loc_h[iz]  = rho0[iz] * acc_loc_h  / n
    flux_loc_s[iz]  = rho0[iz] * acc_loc_s  / n
    flux_glob_h[iz] = rho0[iz] * acc_glob_h / n
    flux_glob_s[iz] = rho0[iz] * acc_glob_s / n

    if iz % 10 == 0:
        print(f'  iz={iz}/{n_z-1}  ({alt[iz]:.0f} m)')

ds_u.close() ; ds_w.close()
del ds_u, ds_w
gc.collect()

print('Flux calculés.')
# Out:
#   iz=0/73  (0 m)
#   iz=10/73  (1331 m)
#   iz=20/73  (6000 m)
#   iz=30/73  (11000 m)
#   iz=40/73  (16000 m)
#   iz=50/73  (21000 m)
#   iz=60/73  (26000 m)
#   iz=70/73  (31000 m)
# Flux calculés.

# %% [markdown]
# ---
# ## §17 — Étape 1 : visualisation du profil de référence
#
# Observer : zéros en surface et au sommet convectif, localisation de l'extremum, changement de signe éventuel.

# %%
idx_tropo = np.searchsorted(alt, 15000)
sc = 1e3

fig, axes = plt.subplots(1, 2, figsize=(12, 9), sharey=True)

for ax, sl, titre in zip(
    axes,
    [slice(None, idx_tropo), slice(None)],
    ['Troposphère (0–15 km)', 'Colonne complète'],
):
    ax.plot(flux_glob_h[sl] * sc, alt[sl], color='royalblue',   lw=2.5, label='humide (global)')
    ax.plot(flux_glob_s[sl] * sc, alt[sl], color='saddlebrown', lw=2.5, label='sèche  (global)')
    ax.plot(flux_loc_h[sl]  * sc, alt[sl], color='royalblue',   lw=1.5, linestyle='--', label='humide (local)')
    ax.plot(flux_loc_s[sl]  * sc, alt[sl], color='saddlebrown', lw=1.5, linestyle='--', label='sèche  (local)')
    ax.axvline(0, color='grey', alpha=0.5, lw=1)
    ax.set_xlabel('ρ₀ ū\'w\'  (×10⁻³ kg/m²/s²)')
    ax.set_title(titre, fontweight='bold')
    ax.legend(fontsize=9)
    ax.grid(True, alpha=0.3)

axes[0].set_ylabel('Altitude (m)')
plt.suptitle(
    '§17 — Étape 1 : profil ρ₀⟨u\'w\'⟩ par région\n'
    'Observer : zéros, extremum, changement de signe',
    fontsize=13, fontweight='bold'
)
plt.tight_layout()
plt.show()

for label, flux in [('HUMIDE (global)', flux_glob_h), ('SÈCHE  (global)', flux_glob_s)]:
    phi = flux[:idx_tropo]
    iz_min = np.argmin(phi)
    iz_max = np.argmax(phi)
    print(f'── Région {label} ──')
    print(f'  min  : {phi[iz_min]*sc:.4f} ×10⁻³  à z = {alt[iz_min]:.0f} m')
    print(f'  max  : {phi[iz_max]*sc:.4f} ×10⁻³  à z = {alt[iz_max]:.0f} m')
    print(f'  surface (iz=0)   : {flux[0]*sc:.4f} ×10⁻³')
    print(f'  z≈15 km          : {flux[idx_tropo]*sc:.4f} ×10⁻³')
    print()
# Out:
# ── Région HUMIDE (global) ──
#   min  : -30.1505 ×10⁻³  à z = 4500 m
#   max  : 13.0515 ×10⁻³  à z = 194 m
#   surface (iz=0)   : 0.0000 ×10⁻³
#   z≈15 km          : -1.1430 ×10⁻³
#
# ── Région SÈCHE  (global) ──
#   min  : -3.0802 ×10⁻³  à z = 11000 m
#   max  : 2.1031 ×10⁻³  à z = 194 m
#   surface (iz=0)   : 0.0000 ×10⁻³
#   z≈15 km          : -0.1504 ×10⁻³

# %% [markdown]
# ---
# ## §17 — Étape 2 : forme analytique
#
# $$\rho_0\,\overline{u'w'}(z) = A \cdot \frac{z}{z_c} \cdot \left(1 - \frac{z}{z_c}\right)^n, \quad z \leq z_c$$
#
# - $A$ : amplitude (kg/m²/s²)
# - $z_c$ : hauteur du sommet convectif (m)
# - $n$ : asymétrie — le max se trouve à $z^* = z_c / (1+n)$

# %%
def profil_cmt(z, A, zc, n):
    z  = np.asarray(z, dtype=float)
    xi = np.clip(z / zc, 0.0, 1.0)   # borne [0,1] : pas de (base<0)**n -> pas de RuntimeWarning
    return A * xi * (1.0 - xi)**n

z_test  = np.linspace(0, 15000, 300)

fig, ax = plt.subplots(figsize=(6, 7))
for n_test in [0.5, 1.0, 1.5, 2.0, 3.0]:
    ax.plot(profil_cmt(z_test, A=1.0, zc=12000.0, n=n_test), z_test, lw=2, label=f'n = {n_test}')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel('A × f(z/zc)  (normalisé)')
ax.set_ylabel('Altitude (m)')
ax.set_title('Forme analytique CMT — effet du paramètre n\n(A=1, zc=12 km)', fontweight='bold')
ax.legend(fontsize=10)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## §17 — Étape 3 : fit scipy — région humide

# %%
z_fit   = alt[:idx_tropo].astype(float)
phi_fit = flux_glob_h[:idx_tropo]

p0 = [phi_fit.min(), 12000.0, 1.5]

popt_h, _ = curve_fit(profil_cmt, z_fit, phi_fit, p0=p0, maxfev=20000)
A_h, zc_h, n_h = popt_h

print('── Fit région HUMIDE ──')
print(f'  A  = {A_h:.4e} kg/m²/s²')
print(f'  zc = {zc_h/1000:.2f} km')
print(f'  n  = {n_h:.3f}')
# Out:
# ── Fit région HUMIDE ──
#   A  = -1.6696e-01 kg/m²/s²
#   zc = 14.44 km
#   n  = 1.609

# %% [markdown]
# ---
# ## §17 — Étape 4 : R² et résidus

# %%
def r2_score(y_true, y_pred):
    ss_res = np.sum((y_true - y_pred)**2)
    ss_tot = np.sum((y_true - y_true.mean())**2)
    return 1.0 - ss_res / ss_tot

phi_pred_h = profil_cmt(z_fit, *popt_h)
R2_h       = r2_score(phi_fit, phi_pred_h)
residus_h  = phi_fit - phi_pred_h

print(f'R² humide = {R2_h:.4f}')
print(f'Résidu max : {np.abs(residus_h).max()*sc:.4f} ×10⁻³ kg/m²/s²')
print(f'Résidu rms : {np.sqrt((residus_h**2).mean())*sc:.4f} ×10⁻³ kg/m²/s²')

fig, ax = plt.subplots(figsize=(6, 7))
ax.plot(residus_h * sc, z_fit, color='royalblue', lw=2)
ax.axvline(0, color='grey', alpha=0.5)
ax.set_xlabel('Résidu (×10⁻³ kg/m²/s²)')
ax.set_ylabel('Altitude (m)')
ax.set_title(f'§17 — Résidus du fit (région humide)\nR² = {R2_h:.4f}', fontweight='bold')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# R² humide = 0.8266
# Résidu max : 15.8543 ×10⁻³ kg/m²/s²
# Résidu rms : 5.6045 ×10⁻³ kg/m²/s²

# %% [markdown]
# ---
# ## §17 — Étape 5 : visualisation simulation vs fit

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 9), sharey=True)

for ax, sl, titre in zip(
    axes,
    [slice(None, idx_tropo), slice(None)],
    ['Troposphère (0–15 km)', 'Colonne complète'],
):
    ax.plot(flux_glob_h[sl] * sc, alt[sl],
            color='royalblue', lw=2.5, label='simulation (humide global)')
    ax.plot(profil_cmt(alt[sl].astype(float), *popt_h) * sc, alt[sl],
            color='red', lw=2, linestyle='--',
            label=f'fit  A={A_h:.2e}  zc={zc_h/1e3:.1f}km  n={n_h:.2f}  R²={R2_h:.3f}')
    ax.axvline(0, color='grey', alpha=0.4)
    ax.set_xlabel('ρ₀ ū\'w\'  (×10⁻³ kg/m²/s²)')
    ax.set_title(titre, fontweight='bold')
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

axes[0].set_ylabel('Altitude (m)')
plt.suptitle(
    '§17 — Paramétrisation CMT : simulation vs fit analytique\n',
    
    fontsize=13, fontweight='bold'
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## §17 — Étape 6 : fit sur la région sèche + comparaison

# %%
phi_fit_s = flux_glob_s[:idx_tropo]
p0_s = [phi_fit_s.min(), 12000.0, 1.5]

popt_s, _ = curve_fit(profil_cmt, z_fit, phi_fit_s, p0=p0_s, maxfev=20000)
A_s, zc_s, n_s = popt_s

R2_s = r2_score(phi_fit_s, profil_cmt(z_fit, *popt_s))

print('── Fit région SÈCHE ──')
print(f'  A  = {A_s:.4e} kg/m²/s²')
print(f'  zc = {zc_s/1000:.2f} km')
print(f'  n  = {n_s:.3f}')
print(f'  R² = {R2_s:.4f}')

fig, axes = plt.subplots(1, 2, figsize=(13, 9), sharey=True)

for ax, sl, titre in zip(
    axes,
    [slice(None, idx_tropo), slice(None)],
    ['Troposphère (0–15 km)', 'Colonne complète'],
):
    ax.plot(flux_glob_h[sl] * sc, alt[sl], color='royalblue',   lw=2.5, label='simulation humide')
    ax.plot(profil_cmt(alt[sl].astype(float), *popt_h) * sc, alt[sl],
            color='royalblue', lw=1.8, linestyle='--', label=f'fit humide  R²={R2_h:.3f}')
    ax.plot(flux_glob_s[sl] * sc, alt[sl], color='saddlebrown', lw=2.5, label='simulation sèche')
    ax.plot(profil_cmt(alt[sl].astype(float), *popt_s) * sc, alt[sl],
            color='saddlebrown', lw=1.8, linestyle='--', label=f'fit sèche   R²={R2_s:.3f}')
    ax.axvline(0, color='grey', alpha=0.4)
    ax.set_xlabel('ρ₀ ū\'w\'  (×10⁻³ kg/m²/s²)')
    ax.set_title(titre, fontweight='bold')
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

axes[0].set_ylabel('Altitude (m)')
plt.suptitle('§17 — Fit analytique : humide vs sèche', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5723/659856804.py:4: RuntimeWarning: divide by zero encountered in power
#   return A * xi * (1.0 - xi)**n
# ── Fit région SÈCHE ──
#   A  = -2.5269e-03 kg/m²/s²
#   zc = 12.73 km
#   n  = 0.000
#   R² = 0.5643

# %% [markdown]
# ---
# ## §17 — Étape 7 : tableau de synthèse

# %%
z_max_h = zc_h / (1 + n_h)
z_max_s = zc_s / (1 + n_s)

print('=' * 55)
print(f'{"Paramètre":<22} {"Humide":>14} {"Sèche":>14}')
print('=' * 55)
print(f'{"A (kg/m²/s²)":<22} {A_h:>14.4e} {A_s:>14.4e}')
print(f'{"zc (km)":<22} {zc_h/1000:>14.2f} {zc_s/1000:>14.2f}')
print(f'{"n":<22} {n_h:>14.3f} {n_s:>14.3f}')
print(f'{"R²":<22} {R2_h:>14.4f} {R2_s:>14.4f}')
print(f'{"z_max = zc/(1+n) (km)":<22} {z_max_h/1000:>14.2f} {z_max_s/1000:>14.2f}')
print('=' * 55)
# Out:
# =======================================================
# Paramètre                      Humide          Sèche
# =======================================================
# A (kg/m²/s²)              -1.6696e-01    -2.5269e-03
# zc (km)                         14.44          12.73
# n                               1.609          0.000
# R²                             0.8266         0.5643
# z_max = zc/(1+n) (km)            5.54          12.73
# =======================================================

# %% [markdown]
# ---
# ## §17 — Étape 8 : robustesse temporelle (early vs late)

# %%
t_mid = t_stat + (n_t - t_stat) // 2

flux_early_h = np.zeros(n_z)
flux_late_h  = np.zeros(n_z)

ds_u = xr.open_dataset(path3d('ua'))
ds_w = xr.open_dataset(path3d('wa'))

for iz in range(n_z):
    for flux_arr, t0, t1 in [
        (flux_early_h, t_stat, t_mid),
        (flux_late_h,  t_mid,  n_t),
    ]:
        acc = 0.0
        n   = 0
        for it in range(t0, t1):
            u_2d = ds_u['ua'].isel({dim_t: it, dim_z: iz}).values
            w_2d = ds_w['wa'].isel({dim_t: it, dim_z: iz}).values
            u_p  = u_2d - u_2d.mean()
            w_p  = w_2d - w_2d.mean()
            acc += (u_p * w_p)[mh].mean()
            n   += 1
            del u_2d, w_2d, u_p, w_p
        flux_arr[iz] = rho0[iz] * acc / n

    if iz % 10 == 0:
        print(f'  iz={iz}/{n_z-1}')

ds_u.close() ; ds_w.close()
del ds_u, ds_w
gc.collect()

popt_early, _ = curve_fit(profil_cmt, z_fit, flux_early_h[:idx_tropo], p0=p0, maxfev=20000)
popt_late,  _ = curve_fit(profil_cmt, z_fit, flux_late_h[:idx_tropo],  p0=p0, maxfev=20000)

R2_early = r2_score(flux_early_h[:idx_tropo], profil_cmt(z_fit, *popt_early))
R2_late  = r2_score(flux_late_h[:idx_tropo],  profil_cmt(z_fit, *popt_late))

print()
print(f'{"":<8} {"A (kg/m²/s²)":>16} {"zc (km)":>10} {"n":>8} {"R²":>8}')
print(f'{"early":<8} {popt_early[0]:>16.4e} {popt_early[1]/1e3:>10.2f} {popt_early[2]:>8.3f} {R2_early:>8.4f}')
print(f'{"late":<8} {popt_late[0]:>16.4e} {popt_late[1]/1e3:>10.2f} {popt_late[2]:>8.3f} {R2_late:>8.4f}')
print(f'{"full":<8} {A_h:>16.4e} {zc_h/1e3:>10.2f} {n_h:>8.3f} {R2_h:>8.4f}')

fig, ax = plt.subplots(figsize=(7, 9))
ax.plot(flux_glob_h[:idx_tropo]   * sc, z_fit, color='royalblue',  lw=2.5, label='simulation (full)')
ax.plot(flux_early_h[:idx_tropo]  * sc, z_fit, color='steelblue',  lw=1.5, linestyle='--', label='simulation early')
ax.plot(flux_late_h[:idx_tropo]   * sc, z_fit, color='navy',       lw=1.5, linestyle=':',  label='simulation late')
ax.plot(profil_cmt(z_fit, *popt_h)     * sc, z_fit, color='red',       lw=2,   label=f'fit full    R²={R2_h:.3f}')
ax.plot(profil_cmt(z_fit, *popt_early) * sc, z_fit, color='orange',    lw=1.5, linestyle='--', label=f'fit early   R²={R2_early:.3f}')
ax.plot(profil_cmt(z_fit, *popt_late)  * sc, z_fit, color='darkorange', lw=1.5, linestyle=':', label=f'fit late    R²={R2_late:.3f}')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel('ρ₀ ū\'w\'  (×10⁻³ kg/m²/s²)')
ax.set_ylabel('Altitude (m)')
ax.set_title('§17 — Robustesse temporelle (humide)\nearly = 1ère moitié stat / late = 2ème moitié', fontweight='bold')
ax.legend(fontsize=8)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
#   iz=0/73
#   iz=10/73
#   iz=20/73
#   iz=30/73
#   iz=40/73
#   iz=50/73
#   iz=60/73
#   iz=70/73
#
#              A (kg/m²/s²)    zc (km)        n       R²
# early         -1.5624e-01      14.94    1.691   0.7995
# late          -1.7586e-01      13.97    1.519   0.8279
# full          -1.6696e-01      14.44    1.609   0.8266

# %% [markdown]
# # Profil des vents u et v par région

# %%
lux_loc_h  = np.zeros(n_z)
flux_loc_s  = np.zeros(n_z)
flux_glob_h = np.zeros(n_z)
flux_glob_s = np.zeros(n_z)
ubar_h      = np.zeros(n_z)
ubar_s      = np.zeros(n_z)
vbar_h      = np.zeros(n_z)
vbar_s      = np.zeros(n_z)

ds_u = xr.open_dataset(path3d('ua'))
ds_v = xr.open_dataset(path3d('va'))
ds_w = xr.open_dataset(path3d('wa'))

for iz in range(n_z//2):

    acc_loc_h  = 0.0 ; acc_loc_s  = 0.0
    acc_glob_h = 0.0 ; acc_glob_s = 0.0
    acc_ubar_h = 0.0 ; acc_ubar_s = 0.0
    acc_vbar_h = 0.0 ; acc_vbar_s = 0.0
    n = 0

    for it in range(t_stat, n_t):

        u_2d = ds_u['ua'].isel({dim_t: it, dim_z: iz}).values
        v_2d = ds_v['va'].isel({dim_t: it, dim_z: iz}).values
        w_2d = ds_w['wa'].isel({dim_t: it, dim_z: iz}).values

        # anomalies locales (intra-région)
        u_h = u_2d[mh] ; u_s = u_2d[ms]
        w_h = w_2d[mh] ; w_s = w_2d[ms]
        acc_loc_h += ((u_h - u_h.mean()) * (w_h - w_h.mean())).mean()
        acc_loc_s += ((u_s - u_s.mean()) * (w_s - w_s.mean())).mean()

        # anomalies globales (domaine entier)
        u_p = u_2d - u_2d.mean()
        w_p = w_2d - w_2d.mean()
        acc_glob_h += (u_p * w_p)[mh].mean()
        acc_glob_s += (u_p * w_p)[ms].mean()

        # vents moyens par région
        acc_ubar_h += u_h.mean()
        acc_ubar_s += u_s.mean()
        acc_vbar_h += v_2d[mh].mean()
        acc_vbar_s += v_2d[ms].mean()

        n += 1
        del u_2d, v_2d, w_2d, u_h, u_s, w_h, w_s, u_p, w_p
        gc.collect()

    flux_loc_h[iz]  = rho0[iz] * acc_loc_h  / n
    flux_loc_s[iz]  = rho0[iz] * acc_loc_s  / n
    flux_glob_h[iz] = rho0[iz] * acc_glob_h / n
    flux_glob_s[iz] = rho0[iz] * acc_glob_s / n
    ubar_h[iz]      = acc_ubar_h / n
    ubar_s[iz]      = acc_ubar_s / n
    vbar_h[iz]      = acc_vbar_h / n
    vbar_s[iz]      = acc_vbar_s / n

    if iz % 10 == 0:
        print(f'  iz={iz}/{n_z-1}  ({alt[iz]:.0f} m)')

ds_u.close() ; ds_v.close() ; ds_w.close()
del ds_u, ds_v, ds_w
gc.collect()

print('Flux et vents moyens calculés.')
# Out:
#   iz=0/73  (0 m)
#   iz=10/73  (1331 m)
#   iz=20/73  (6000 m)
#   iz=30/73  (11000 m)
# Flux et vents moyens calculés.

# %%
# ======================================================================
# Profils de vent moyen ū et v̄ par région (humide / sèche)
# ======================================================================

fig, ax = plt.subplots(figsize=(7, 8))
idx_18km = np.searchsorted(alt, 18000)
sl = slice(None, idx_18km)

ax.plot(ubar_h[sl], alt[sl], color='royalblue',   lw=2,               label=r'$\bar{u}$ humide')
ax.plot(ubar_s[sl], alt[sl], color='royalblue',   lw=2, linestyle='--', label=r'$\bar{u}$ sèche')
ax.plot(vbar_h[sl], alt[sl], color='saddlebrown', lw=2,               label=r'$\bar{v}$ humide')
ax.plot(vbar_s[sl], alt[sl], color='saddlebrown', lw=2, linestyle='--', label=r'$\bar{v}$ sèche')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel('Vitesse (m/s)')
ax.set_ylabel('Altitude (m)')
ax.set_title('Profils de vent moyen par région — humide vs sèche\n(0–18 km)', fontweight='bold')
ax.legend(fontsize=9)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Paramétrisation selon deux axes

# %%
n_stat_it = n_t - t_stat



iz_lo_glob = np.searchsorted(alt, 2000)
iz_hi_glob = np.searchsorted(alt, 18000)
n_z_fit    = iz_hi_glob - iz_lo_glob
z_fit_ab   = alt[iz_lo_glob:iz_hi_glob]

alpha_h = np.zeros(n_z_fit)
beta_h  = np.zeros(n_z_fit)
alpha_s = np.zeros(n_z_fit)
beta_s  = np.zeros(n_z_fit)

y_mean_h  = np.zeros(n_z_fit)
y_mean_s  = np.zeros(n_z_fit)
yhat_mean_h = np.zeros(n_z_fit)
yhat_mean_s = np.zeros(n_z_fit)

ds_u = xr.open_dataset(path3d('ua'))
ds_w = xr.open_dataset(path3d('wa'))

# ── ubar_glob(iz) : moyenne domaine entier sur l'état stationnaire ────
ubar_glob = np.zeros(n_z_fit)
for i_iz, iz in enumerate(range(iz_lo_glob, iz_hi_glob)):
    for it in range(t_stat, n_t):
        ubar_glob[i_iz] += ds_u['ua'].isel({dim_t: it, dim_z: iz}).values.mean()
    ubar_glob[i_iz] /= n_stat_it
print('ubar_glob calculé.')

# ── Boucle principale : un niveau à la fois ───────────────────────────
for i_iz, iz in enumerate(range(iz_lo_glob, iz_hi_glob)):

    iz_lo = iz - 1
    iz_hi = iz + 1
    dz    = alt[iz_hi] - alt[iz_lo]

    u_all = ds_u['ua'].isel({dim_z: iz,    dim_t: slice(t_stat, n_t)}).values
    u_lo  = ds_u['ua'].isel({dim_z: iz_lo, dim_t: slice(t_stat, n_t)}).values
    u_hi  = ds_u['ua'].isel({dim_z: iz_hi, dim_t: slice(t_stat, n_t)}).values
    w_lo  = ds_w['wa'].isel({dim_z: iz_lo, dim_t: slice(t_stat, n_t)}).values
    w_hi  = ds_w['wa'].isel({dim_z: iz_hi, dim_t: slice(t_stat, n_t)}).values

    # ── scalaires y(t), x1(t), x2(t) pour chaque région ─────────────
    y_t_h  = np.zeros(n_stat_it) ; y_t_s  = np.zeros(n_stat_it)
    x1_t_h = np.zeros(n_stat_it) ; x1_t_s = np.zeros(n_stat_it)
    x2_t_h = np.zeros(n_stat_it) ; x2_t_s = np.zeros(n_stat_it)

    for i_t in range(n_stat_it):

        # y : divergence du flux Reynolds moyen sur la région
        u_p_lo = u_lo[i_t] - u_lo[i_t].mean()
        w_p_lo = w_lo[i_t] - w_lo[i_t].mean()
        u_p_hi = u_hi[i_t] - u_hi[i_t].mean()
        w_p_hi = w_hi[i_t] - w_hi[i_t].mean()

        flux_lo_h = (rho0[iz_lo] * u_p_lo * w_p_lo)[mh].mean()
        flux_hi_h = (rho0[iz_hi] * u_p_hi * w_p_hi)[mh].mean()
        flux_lo_s = (rho0[iz_lo] * u_p_lo * w_p_lo)[ms].mean()
        flux_hi_s = (rho0[iz_hi] * u_p_hi * w_p_hi)[ms].mean()

        y_t_h[i_t] = -(flux_hi_h - flux_lo_h) / (dz * rho0[iz])
        y_t_s[i_t] = -(flux_hi_s - flux_lo_s) / (dz * rho0[iz])

        # x1 : rho0 * ubar_reg
        x1_t_h[i_t] = rho0[iz] * u_all[i_t][mh].mean()
        x1_t_s[i_t] = rho0[iz] * u_all[i_t][ms].mean()

        # x2 : dz(rho0 * ubar_reg) par différences finies centrées
        x2_t_h[i_t] = (rho0[iz_hi] * u_hi[i_t][mh].mean()
                      - rho0[iz_lo] * u_lo[i_t][mh].mean()) / dz
        x2_t_s[i_t] = (rho0[iz_hi] * u_hi[i_t][ms].mean()
                      - rho0[iz_lo] * u_lo[i_t][ms].mean()) / dz

    # ── OLS sur t par région ──────────────────────────────────────────
    for y_t, x1_t, x2_t, alpha_arr, beta_arr, tag in [
        (y_t_h, x1_t_h, x2_t_h, alpha_h, beta_h, 'h'),
        (y_t_s, x1_t_s, x2_t_s, alpha_s, beta_s, 's'),
    ]:
        S11 = x1_t @ x1_t
        S12 = x1_t @ x2_t
        S22 = x2_t @ x2_t
        b1  = x1_t @ y_t
        b2  = x2_t @ y_t

        det = S11 * S22 - S12 * S12
        a   = ( S22 * b1 - S12 * b2) / det
        b   = (-S12 * b1 + S11 * b2) / det

        if tag == 'h':
            alpha_h[i_iz] = a ; beta_h[i_iz] = b
            y_mean_h[i_iz]    = y_t.mean()
            yhat_mean_h[i_iz] = (a * x1_t + b * x2_t).mean()
        else:
            alpha_s[i_iz] = a ; beta_s[i_iz] = b
            y_mean_s[i_iz]    = y_t.mean()
            yhat_mean_s[i_iz] = (a * x1_t + b * x2_t).mean()

    del u_all, u_lo, u_hi, w_lo, w_hi
    gc.collect()

    if i_iz % 10 == 0:
        print(f'  i_iz={i_iz}/{n_z_fit-1}  ({alt[iz]:.0f} m)')

ds_u.close() ; ds_w.close()
del ds_u, ds_w
gc.collect()
print('α(z), β(z) calculés.')
# Out:
# ubar_glob calculé.
#   i_iz=0/31  (2055 m)
#   i_iz=10/31  (7000 m)
#   i_iz=20/31  (12000 m)
#   i_iz=30/31  (17000 m)
# α(z), β(z) calculés.

# %%
# ── Visualisation α(z) et β(z) + comparaison y vs ŷ ──────────────────
fig, axes = plt.subplots(1, 4, figsize=(20, 8), sharey=True)

axes[0].plot(alpha_h, z_fit_ab, color='royalblue',   lw=2, label='humide')
axes[0].plot(alpha_s, z_fit_ab, color='saddlebrown', lw=2, label='sèche')
axes[0].axvline(0, color='grey', alpha=0.4)
axes[0].set_xlabel('α(z)')
axes[0].set_title('α(z)', fontweight='bold')
axes[0].legend() ; axes[0].grid(True, alpha=0.3)

axes[1].plot(beta_h, z_fit_ab, color='royalblue',   lw=2, label='humide')
axes[1].plot(beta_s, z_fit_ab, color='saddlebrown', lw=2, label='sèche')
axes[1].axvline(0, color='grey', alpha=0.4)
axes[1].set_xlabel('β(z)')
axes[1].set_title('β(z)', fontweight='bold')
axes[1].legend() ; axes[1].grid(True, alpha=0.3)

axes[2].plot(y_mean_h    * 1e5, z_fit_ab, color='royalblue', lw=2.5, label=r'$\bar{y}$')
axes[2].plot(yhat_mean_h * 1e5, z_fit_ab, color='black',     lw=2, linestyle='--', label=r'$\hat{y}$')
axes[2].axvline(0, color='grey', alpha=0.4)
axes[2].set_xlabel('Tendance (×10⁻⁵ m/s²)')
axes[2].set_title('HUMIDE — y vs ŷ', fontweight='bold')
axes[2].legend() ; axes[2].grid(True, alpha=0.3)

axes[3].plot(y_mean_s    * 1e5, z_fit_ab, color='saddlebrown', lw=2.5, label=r'$\bar{y}$')
axes[3].plot(yhat_mean_s * 1e5, z_fit_ab, color='black',       lw=2, linestyle='--', label=r'$\hat{y}$')
axes[3].axvline(0, color='grey', alpha=0.4)
axes[3].set_xlabel('Tendance (×10⁻⁵ m/s²)')
axes[3].set_title('SÈCHE — y vs ŷ', fontweight='bold')
axes[3].legend() ; axes[3].grid(True, alpha=0.3)

axes[0].set_ylabel('Altitude (m)')
plt.suptitle(r'§18u — OLS sur $t$ : $\alpha(z)$, $\beta(z)$ et reconstruction',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# ══════════════════════════════════════════════════════════════════════
# §18v — α(z,t) et β(z,t) via système 2×2 (éq. u + éq. v)
# ══════════════════════════════════════════════════════════════════════

iz_lo_glob = np.searchsorted(alt, 2000)
iz_hi_glob = np.searchsorted(alt, 18000)
n_z_fit    = iz_hi_glob - iz_lo_glob
z_fit_ab   = alt[iz_lo_glob:iz_hi_glob]
n_stat_it  = n_t - t_stat

# résultats : shape (n_z_fit, n_stat_it)
alpha_zt_h = np.full((n_z_fit, n_stat_it), np.nan)
beta_zt_h  = np.full((n_z_fit, n_stat_it), np.nan)
alpha_zt_s = np.full((n_z_fit, n_stat_it), np.nan)
beta_zt_s  = np.full((n_z_fit, n_stat_it), np.nan)

ds_u = xr.open_dataset(path3d('ua'))
ds_v = xr.open_dataset(path3d('va'))
ds_w = xr.open_dataset(path3d('wa'))

for i_iz, iz in enumerate(range(iz_lo_glob, iz_hi_glob)):

    iz_lo = iz - 1
    iz_hi = iz + 1
    dz    = alt[iz_hi] - alt[iz_lo]

    # charger les 3 niveaux nécessaires, tous les pas de temps stat
    u_all = ds_u['ua'].isel({dim_z: iz,    dim_t: slice(t_stat, n_t)}).values  # (nt, ny, nx)
    u_lo  = ds_u['ua'].isel({dim_z: iz_lo, dim_t: slice(t_stat, n_t)}).values
    u_hi  = ds_u['ua'].isel({dim_z: iz_hi, dim_t: slice(t_stat, n_t)}).values
    v_all = ds_v['va'].isel({dim_z: iz,    dim_t: slice(t_stat, n_t)}).values
    v_lo  = ds_v['va'].isel({dim_z: iz_lo, dim_t: slice(t_stat, n_t)}).values
    v_hi  = ds_v['va'].isel({dim_z: iz_hi, dim_t: slice(t_stat, n_t)}).values
    w_lo  = ds_w['wa'].isel({dim_z: iz_lo, dim_t: slice(t_stat, n_t)}).values
    w_hi  = ds_w['wa'].isel({dim_z: iz_hi, dim_t: slice(t_stat, n_t)}).values

    for i_t in range(n_stat_it):

        # ── anomalies de vent vertical aux niveaux voisins ──
        u_p_lo = u_lo[i_t] - u_lo[i_t].mean()
        u_p_hi = u_hi[i_t] - u_hi[i_t].mean()
        w_p_lo = w_lo[i_t] - w_lo[i_t].mean()
        w_p_hi = w_hi[i_t] - w_hi[i_t].mean()

        # ── membres droits : dz(rho0 * u'w') / rho0 par région ──
        y_u_h = (  (rho0[iz_hi] * u_p_hi * w_p_hi)[mh].mean()
                 - (rho0[iz_lo] * u_p_lo * w_p_lo)[mh].mean() ) / dz
        y_u_s = (  (rho0[iz_hi] * u_p_hi * w_p_hi)[ms].mean()
                 - (rho0[iz_lo] * u_p_lo * w_p_lo)[ms].mean() ) / dz

        # idem pour v
        v_p_lo = v_lo[i_t] - v_lo[i_t].mean()
        v_p_hi = v_hi[i_t] - v_hi[i_t].mean()

        y_v_h = (  (rho0[iz_hi] * v_p_hi * w_p_hi)[mh].mean()
                 - (rho0[iz_lo] * v_p_lo * w_p_lo)[mh].mean() ) / dz
        y_v_s = (  (rho0[iz_hi] * v_p_hi * w_p_hi)[ms].mean()
                 - (rho0[iz_lo] * v_p_lo * w_p_lo)[ms].mean() ) / dz

        # ── membres gauche : rho0*ubar_c et dz(rho0*ubar_c) par région ──
        for mask, tag in [(mh, 'h'), (ms, 's')]:

            # ligne 1 du système (éq. u)
            A11 = rho0[iz] * u_all[i_t][mask].mean()
            A12 = (rho0[iz_hi] * u_hi[i_t][mask].mean()
                 - rho0[iz_lo] * u_lo[i_t][mask].mean()) / dz

            # ligne 2 du système (éq. v)
            A21 = rho0[iz] * v_all[i_t][mask].mean()
            A22 = (rho0[iz_hi] * v_hi[i_t][mask].mean()
                 - rho0[iz_lo] * v_lo[i_t][mask].mean()) / dz

            y1 = y_u_h if tag == 'h' else y_u_s
            y2 = y_v_h if tag == 'h' else y_v_s

            M  = np.array([[A11, A12],
                           [A21, A22]])
            rhs = np.array([y1, y2])

            det = A11 * A22 - A12 * A21
            if np.abs(det) < 1e-30:   # système singulier → NaN
                continue

            sol = np.linalg.solve(M, rhs)

            if tag == 'h':
                alpha_zt_h[i_iz, i_t] = sol[0]
                beta_zt_h [i_iz, i_t] = sol[1]
            else:
                alpha_zt_s[i_iz, i_t] = sol[0]
                beta_zt_s [i_iz, i_t] = sol[1]

    del u_all, u_lo, u_hi, v_all, v_lo, v_hi, w_lo, w_hi
    gc.collect()

    if i_iz % 10 == 0:
        print(f'  i_iz={i_iz}/{n_z_fit-1}  ({alt[iz]:.0f} m)')

ds_u.close() ; ds_v.close() ; ds_w.close()
del ds_u, ds_v, ds_w
gc.collect()
print('α(z,t) et β(z,t) calculés.')
# Out:
#   i_iz=0/31  (2055 m)
#   i_iz=10/31  (7000 m)
#   i_iz=20/31  (12000 m)
#   i_iz=30/31  (17000 m)
# α(z,t) et β(z,t) calculés.

# %%
# ── Vérification reconstruction §18v ──────────────────────────────────
# Prendre un niveau et un pas de temps arbitraires
i_iz_test = 20
i_t_test  = 5
iz        = iz_lo_glob + i_iz_test
iz_lo     = iz - 1
iz_hi     = iz + 1
dz        = alt[iz_hi] - alt[iz_lo]

ds_u = xr.open_dataset(path3d('ua'))
ds_v = xr.open_dataset(path3d('va'))
ds_w = xr.open_dataset(path3d('wa'))

it = t_stat + i_t_test

u_2d  = ds_u['ua'].isel({dim_t: it, dim_z: iz   }).values
u_lo_ = ds_u['ua'].isel({dim_t: it, dim_z: iz_lo}).values
u_hi_ = ds_u['ua'].isel({dim_t: it, dim_z: iz_hi}).values
v_2d  = ds_v['va'].isel({dim_t: it, dim_z: iz   }).values
v_lo_ = ds_v['va'].isel({dim_t: it, dim_z: iz_lo}).values
v_hi_ = ds_v['va'].isel({dim_t: it, dim_z: iz_hi}).values
w_lo_ = ds_w['wa'].isel({dim_t: it, dim_z: iz_lo}).values
w_hi_ = ds_w['wa'].isel({dim_t: it, dim_z: iz_hi}).values

ds_u.close(); ds_v.close(); ds_w.close()

# ── recalcul y_u et y_v (membres droits) ──
u_p_lo = u_lo_ - u_lo_.mean(); u_p_hi = u_hi_ - u_hi_.mean()
v_p_lo = v_lo_ - v_lo_.mean(); v_p_hi = v_hi_ - v_hi_.mean()
w_p_lo = w_lo_ - w_lo_.mean(); w_p_hi = w_hi_ - w_hi_.mean()

y_u_h = ((rho0[iz_hi]*u_p_hi*w_p_hi)[mh].mean()
        - (rho0[iz_lo]*u_p_lo*w_p_lo)[mh].mean()) / dz
y_v_h = ((rho0[iz_hi]*v_p_hi*w_p_hi)[mh].mean()
        - (rho0[iz_lo]*v_p_lo*w_p_lo)[mh].mean()) / dz

# ── recalcul x1, x2 pour u et v (membres gauches) ──
x1_u = rho0[iz] * u_2d[mh].mean()
x2_u = (rho0[iz_hi]*u_hi_[mh].mean() - rho0[iz_lo]*u_lo_[mh].mean()) / dz
x1_v = rho0[iz] * v_2d[mh].mean()
x2_v = (rho0[iz_hi]*v_hi_[mh].mean() - rho0[iz_lo]*v_lo_[mh].mean()) / dz

# ── reconstruction ──
a = alpha_zt_h[i_iz_test, i_t_test]
b = beta_zt_h [i_iz_test, i_t_test]

yhat_u = a * x1_u + b * x2_u
yhat_v = a * x1_v + b * x2_v

print(f'Niveau z = {alt[iz]:.0f} m,  pas de temps i_t = {i_t_test}')
print(f'  α = {a:.6e},  β = {b:.6e}')
print()
print(f'  y_u  = {y_u_h:.6e}   ŷ_u  = {yhat_u:.6e}   Δ = {abs(y_u_h - yhat_u):.2e}')
print(f'  y_v  = {y_v_h:.6e}   ŷ_v  = {yhat_v:.6e}   Δ = {abs(y_v_h - yhat_v):.2e}')
# Out:
# Niveau z = 12000 m,  pas de temps i_t = 5
#   α = 4.282228e-05,  β = -4.333869e-02
#
#   y_u  = 4.567904e-06   ŷ_u  = 4.567904e-06   Δ = 8.47e-22
#   y_v  = 3.672460e-06   ŷ_v  = 3.672460e-06   Δ = 4.24e-22

# %%
i_t_show = np.arange(n_stat_it)
cmap     = plt.cm.viridis

fig, axes = plt.subplots(2, 2, figsize=(14, 12), sharey=True)
titles = [('HUMIDE', alpha_zt_h, beta_zt_h),
          ('SÈCHE',  alpha_zt_s, beta_zt_s)]

for col, (region, alpha_zt, beta_zt) in enumerate(titles):
    for k, i_t in enumerate(i_t_show):
        c = cmap(k / (n_stat_it - 1))
        axes[0, col].plot(alpha_zt[:, i_t], z_fit_ab, color=c, lw=0.8, alpha=0.5)
        axes[1, col].plot(beta_zt[:, i_t],  z_fit_ab, color=c, lw=0.8, alpha=0.5)

    # moyenne temporelle par-dessus
    axes[0, col].plot(np.nanmean(alpha_zt, axis=1), z_fit_ab,
                      color='red', lw=2.5, label='moyenne')
    axes[1, col].plot(np.nanmean(beta_zt,  axis=1), z_fit_ab,
                      color='red', lw=2.5, label='moyenne')

    for row, lbl in enumerate([r'$\alpha(z)$', r'$\beta(z)$']):
        axes[row, col].axvline(0, color='grey', alpha=0.4)
        axes[row, col].set_title(f'{region} — {lbl}', fontweight='bold')
        axes[row, col].grid(True, alpha=0.3)
        axes[row, col].legend(fontsize=9)
        if col == 0:
            axes[row, col].set_ylabel('Altitude (m)')

    axes[1, col].set_xlabel('valeur du paramètre')

sm = plt.cm.ScalarMappable(cmap=cmap,
     norm=plt.Normalize(vmin=t_stat, vmax=t_stat + n_stat_it - 1))
sm.set_array([])
fig.colorbar(sm, ax=axes, orientation='vertical', fraction=0.002, pad=0.002,
             label='pas de temps')
plt.suptitle(r'§18v — Profils verticaux $\alpha(z,t)$ et $\beta(z,t)$ — tous les $t$',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5723/3435710634.py:37: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# ── Figure 2 : distributions temporelles à quelques z choisis ─────────
z_targets  = [2000, 4000, 6000, 8000, 10000]  # altitudes cibles (m)
iz_targets = [np.argmin(np.abs(z_fit_ab - zt)) for zt in z_targets]

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
pairs = [('HUMIDE α', alpha_zt_h, axes[0, 0]),
         ('HUMIDE β', beta_zt_h,  axes[0, 1]),
         ('SÈCHE α',  alpha_zt_s, axes[1, 0]),
         ('SÈCHE β',  beta_zt_s,  axes[1, 1])]

colors_z = plt.cm.plasma(np.linspace(0.1, 0.9, len(iz_targets)))

for title, arr, ax in pairs:
    for iz_t, zt, c in zip(iz_targets, z_targets, colors_z):
        data = arr[iz_t, :]
        data = data[~np.isnan(data)]
        ax.hist(data, bins=30, color=c, alpha=0.55, density=True,
                label=f'z={zt//1000} km')
    ax.axvline(0, color='grey', alpha=0.5)
    ax.set_title(title, fontweight='bold')
    ax.set_xlabel('valeur du paramètre')
    ax.set_ylabel('densité')
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

plt.suptitle(r'§18v — Distributions temporelles de $\alpha$ et $\beta$ par niveau',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 12), sharey=True)
titles = [('HUMIDE', alpha_zt_h, beta_zt_h),
          ('SÈCHE',  alpha_zt_s, beta_zt_s)]

for col, (region, alpha_zt, beta_zt) in enumerate(titles):
    for row, (arr, lbl) in enumerate([(alpha_zt, r'$\alpha(z)$'),
                                       (beta_zt,  r'$\beta(z)$')]):
        ax = axes[row, col]

        # ── seuils ±3σ globaux (sur tous z et t) ──
        mu  = np.nanmean(arr)
        sig = np.nanstd(arr)
        lo, hi = mu - 2*sig, mu + 2*sig

        for k in range(n_stat_it):
            profil = arr[:, k].copy()
            profil[(profil < lo) | (profil > hi)] = np.nan
            c = cmap(k / (n_stat_it - 1))
            ax.plot(profil, z_fit_ab, color=c, lw=0.8, alpha=0.5)

        # moyenne temporelle (après filtrage)
        arr_filt = arr.copy()
        arr_filt[(arr_filt < lo) | (arr_filt > hi)] = np.nan
        ax.plot(np.nanmean(arr_filt, axis=1), z_fit_ab,
                color='red', lw=2.5, label='moyenne')

        ax.axvline(0, color='grey', alpha=0.4)
        ax.set_title(f'{region} — {lbl}', fontweight='bold')
        ax.grid(True, alpha=0.3)
        ax.legend(fontsize=9)
        if col == 0:
            ax.set_ylabel('Altitude (m)')
        if row == 1:
            ax.set_xlabel('valeur du paramètre')

sm = plt.cm.ScalarMappable(cmap=cmap,
     norm=plt.Normalize(vmin=t_stat, vmax=t_stat + n_stat_it - 1))
sm.set_array([])
fig.colorbar(sm, ax=axes, orientation='vertical', fraction=0.02, pad=0.02,
             label='pas de temps')
plt.suptitle(r'§18v — $\alpha(z,t)$ et $\beta(z,t)$ — outliers exclus (±2σ)',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5723/2408183399.py:43: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
pairs = [('HUMIDE α', alpha_zt_h, axes[0, 0]),
         ('HUMIDE β', beta_zt_h,  axes[0, 1]),
         ('SÈCHE α',  alpha_zt_s, axes[1, 0]),
         ('SÈCHE β',  beta_zt_s,  axes[1, 1])]

colors_z = plt.cm.plasma(np.linspace(0.1, 0.9, len(iz_targets)))

for title, arr, ax in pairs:
    # ── filtre ±3σ global ──
    mu  = np.nanmean(arr)
    sig = np.nanstd(arr)
    lo, hi = mu - 2*sig, mu + 2*sig
    arr_filt = arr.copy()
    arr_filt[(arr_filt < lo) | (arr_filt > hi)] = np.nan

    for iz_t, zt, c in zip(iz_targets, z_targets, colors_z):
        data = arr_filt[iz_t, :]
        data = data[~np.isnan(data)]
        ax.hist(data, bins=30, color=c, alpha=0.55, density=True,
                label=f'z={zt//1000} km')

    ax.axvline(0, color='grey', alpha=0.5)
    ax.set_title(title, fontweight='bold')
    ax.set_xlabel('valeur du paramètre')
    ax.set_ylabel('densité')
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

plt.suptitle(r'§18v — Distributions temporelles $\alpha$, $\beta$ par niveau — outliers exclus (±3σ)',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# ── Moyennes temporelles de dz(rho0 u'w') et dz(rho0 v'w') par région ─
dz_flux_u_h = np.zeros(n_z_fit)
dz_flux_u_s = np.zeros(n_z_fit)
dz_flux_v_h = np.zeros(n_z_fit)
dz_flux_v_s = np.zeros(n_z_fit)

ds_u = xr.open_dataset(path3d('ua'))
ds_v = xr.open_dataset(path3d('va'))
ds_w = xr.open_dataset(path3d('wa'))

for i_iz, iz in enumerate(range(iz_lo_glob, iz_hi_glob)):

    iz_lo = iz - 1
    iz_hi = iz + 1
    dz    = alt[iz_hi] - alt[iz_lo]

    acc_u_h = 0.0 ; acc_u_s = 0.0
    acc_v_h = 0.0 ; acc_v_s = 0.0
    n = 0

    for it in range(t_stat, n_t):
        u_lo_ = ds_u['ua'].isel({dim_t: it, dim_z: iz_lo}).values
        u_hi_ = ds_u['ua'].isel({dim_t: it, dim_z: iz_hi}).values
        v_lo_ = ds_v['va'].isel({dim_t: it, dim_z: iz_lo}).values
        v_hi_ = ds_v['va'].isel({dim_t: it, dim_z: iz_hi}).values
        w_lo_ = ds_w['wa'].isel({dim_t: it, dim_z: iz_lo}).values
        w_hi_ = ds_w['wa'].isel({dim_t: it, dim_z: iz_hi}).values

        u_p_lo = u_lo_ - u_lo_.mean() ; u_p_hi = u_hi_ - u_hi_.mean()
        v_p_lo = v_lo_ - v_lo_.mean() ; v_p_hi = v_hi_ - v_hi_.mean()
        w_p_lo = w_lo_ - w_lo_.mean() ; w_p_hi = w_hi_ - w_hi_.mean()

        acc_u_h += ((rho0[iz_hi]*u_p_hi*w_p_hi)[mh].mean()
                  - (rho0[iz_lo]*u_p_lo*w_p_lo)[mh].mean()) / dz
        acc_u_s += ((rho0[iz_hi]*u_p_hi*w_p_hi)[ms].mean()
                  - (rho0[iz_lo]*u_p_lo*w_p_lo)[ms].mean()) / dz
        acc_v_h += ((rho0[iz_hi]*v_p_hi*w_p_hi)[mh].mean()
                  - (rho0[iz_lo]*v_p_lo*w_p_lo)[mh].mean()) / dz
        acc_v_s += ((rho0[iz_hi]*v_p_hi*w_p_hi)[ms].mean()
                  - (rho0[iz_lo]*v_p_lo*w_p_lo)[ms].mean()) / dz
        n += 1
        del u_lo_, u_hi_, v_lo_, v_hi_, w_lo_, w_hi_
        del u_p_lo, u_p_hi, v_p_lo, v_p_hi, w_p_lo, w_p_hi
        gc.collect()

    dz_flux_u_h[i_iz] = acc_u_h / n
    dz_flux_u_s[i_iz] = acc_u_s / n
    dz_flux_v_h[i_iz] = acc_v_h / n
    dz_flux_v_s[i_iz] = acc_v_s / n

    if i_iz % 10 == 0:
        print(f'  i_iz={i_iz}/{n_z_fit-1}  ({alt[iz]:.0f} m)')

ds_u.close() ; ds_v.close() ; ds_w.close()
del ds_u, ds_v, ds_w
gc.collect()
print('dz_flux calculés.')

# ── Visualisation ──────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(13, 9), sharey=True)

axes[0].plot(dz_flux_u_h * 1e5, z_fit_ab, color='royalblue',   lw=2.5, label='humide')
axes[0].plot(dz_flux_u_s * 1e5, z_fit_ab, color='saddlebrown', lw=2.5, label='sèche')
axes[0].axvline(0, color='grey', alpha=0.4)
axes[0].set_xlabel(r"$\partial_z(\rho_0\,\overline{u'w'})$  (×10⁻⁵ kg/m³/s²)")
axes[0].set_title(r"$\partial_z(\rho_0\overline{u'w'})$", fontweight='bold')
axes[0].legend(fontsize=10) ; axes[0].grid(True, alpha=0.3)

axes[1].plot(dz_flux_v_h * 1e5, z_fit_ab, color='royalblue',   lw=2.5, label='humide')
axes[1].plot(dz_flux_v_s * 1e5, z_fit_ab, color='saddlebrown', lw=2.5, label='sèche')
axes[1].axvline(0, color='grey', alpha=0.4)
axes[1].set_xlabel(r"$\partial_z(\rho_0\,\overline{v'w'})$  (×10⁻⁵ kg/m³/s²)")
axes[1].set_title(r"$\partial_z(\rho_0\overline{v'w'})$", fontweight='bold')
axes[1].legend(fontsize=10) ; axes[1].grid(True, alpha=0.3)

axes[0].set_ylabel('Altitude (m)')
plt.suptitle(r"$\partial_z(\rho_0\overline{u'w'})$ et $\partial_z(\rho_0\overline{v'w'})$ — 2–18 km",
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
#   i_iz=0/31  (2055 m)
#   i_iz=10/31  (7000 m)
#   i_iz=20/31  (12000 m)
#   i_iz=30/31  (17000 m)
# dz_flux calculés.

# %% [markdown]
# ---
# # §20 — Paramétrisation de la convection : flux de masse $M_c$
#
# On prolonge la paramétrisation du flux de Reynolds par une analyse du
# flux de masse convectif $M_c$, en s'appuyant sur les équations *bulk-plume* de
# Romps (2014, JAS), reproduites ici pour le profil de vent $\bar v$ (éq. 1–3) :
#
# $$
# \partial_z M = (\varepsilon-\delta)\,M
# \qquad(1)
# $$
# $$
# \rho\,\partial_t \bar v = \partial_z\!\big[M(\bar v - v_c)\big]
# \qquad(2)
# $$
# $$
# \partial_z v_c = \varepsilon(\bar v - v_c) + F/M
# \qquad(3)
# $$
#
# où $M$ est le flux de masse convectif (kg m⁻² s⁻¹), $\varepsilon$ et $\delta$ les taux
# fractionnaires d'entraînement / détraînement (m⁻¹), $\bar v$ le vent moyen, $v_c$ le
# vent dans les nuages, et $F$ la force de pression nuage↔environnement.
#
# $$
# \boxed{\;\rho_0\,\overline{u'w'}(z) \;\approx\; M_c(z)\,\big[\bar u(z) - u_c(z)\big]\;}
# $$
#
# L'objet de cette section est donc de :
# 1. **diagnostiquer** $M_c(z)$ directement depuis `wa` (updrafts convectifs), par région humide / sèche ;
# 2. **vérifier** l'identité flux de Reynolds $\approx M_c\,(\bar u - u_c)$ ;
# 3. **tester l'éq. (1)** en diagnostiquant $(\varepsilon-\delta)=\partial_z M/M$ ;

# %% [markdown]
# ## §20.0 — Robustesse numérique du fit
#
# La forme analytique $A\,(z/z_c)(1-z/z_c)^n$ lève une `RuntimeWarning` quand $z>z_c$
# (base négative à une puissance non entière). On la **redéfinit proprement** en bornant
# $\xi=z/z_c\in[0,1]$ : identique sur le domaine utile $z\le z_c$, nulle au-delà, sans warning.

# %%
def profil_cmt(z, A, zc, n):
    """Forme analytique CMT : A·(z/zc)·(1 - z/zc)^n, nulle pour z>zc.

    xi est borné dans [0,1] pour éviter (base<0)**n non entier → plus de RuntimeWarning,
    et reproduit exactement l'ancienne définition sur 0<=z<=zc.
    """
    z  = np.asarray(z, dtype=float)
    xi = np.clip(z / zc, 0.0, 1.0) if zc > 0 else np.zeros_like(z)
    return A * xi * (1.0 - xi)**n

# vérification : identique à l'ancienne forme sur le domaine utile
_zt = np.linspace(0, 15000, 200)
print('profil_cmt redéfinie (sans RuntimeWarning).')
print('  max |f| (A=1, zc=12km, n=1.5) =', np.abs(profil_cmt(_zt, 1.0, 12000., 1.5)).max())
# Out:
# profil_cmt redéfinie (sans RuntimeWarning).
#   max |f| (A=1, zc=12km, n=1.5) = 0.18589929298361713

# %% [markdown]
# ## §20.1 — Définition du flux de masse convectif
#
# Faute de champ de condensat disponible ici, on définit les **cœurs convectifs** par un
# critère dynamique sur la vitesse verticale (cf. Romps : updrafts = air montant cohérent) :
# $\text{updraft} : w > w_{\text{seuil}}(z)$, avec seuil adaptatif par niveau
# $w_\text{seuil}(z)=\max(w_0,\,c\,\sigma_w(z))$.
#
# **Définition correcte du flux de masse** (pondérée par la fraction surfacique $\sigma$ des
# updrafts, sinon on surestime d'un facteur $1/\sigma\sim 10$) :
#
# $$
# M_c(z) \;=\; \rho_0(z)\,\big\langle w\,\mathbb{1}_{\text{up}} \big\rangle_{\text{région}}
# \;=\; \rho_0(z)\,\sigma(z)\,\langle w\rangle_{\text{up}} .
# $$
#
# On calcule en parallèle, **par région** humide (`mh`) / sèche (`ms`), niveau par niveau :
#
# - $M^{+}=\rho_0\langle w\,\mathbb{1}_{w>w_s}\rangle$ (updrafts, pondéré),
# - $M^{-}=\rho_0\langle w\,\mathbb{1}_{w<-w_s}\rangle$ (downdrafts, pondéré),
# - $M_{\text{net}}=\rho_0\,\overline{w}^{\,\text{rég}}$,
# - $\sigma_w(z)$ et la fraction surfacique d'updraft.
#
# > ⚠️ **Sur $M_{\text{net}}$ par région.** La continuité impose $\overline{w}\approx 0$ sur le
# > **domaine entier**, pas région par région. En RCE auto-organisé il y a ascendance nette
# > dans l'humide ($M_{\text{net},h}>0$) compensée par subsidence dans le sec
# > ($M_{\text{net},s}<0$) : c'est la circulation grande-échelle, **physique**, pas un bug.
# > Le bon test de continuité est $\;f_h M_{\text{net},h}+f_s M_{\text{net},s}\approx 0$,
# > avec $f_h,f_s$ les fractions surfaciques des régions (vérifié en §20.2).

# %%
# ── Paramètres du diagnostic de flux de masse ────────────────────────
W0_MIN  = 0.001    # seuil plancher (m/s) pour qualifier un updraft
C_SIGMA = 0.5     # multiplicateur de l'écart-type local sigma_w(z)

# fractions surfaciques des régions (constantes en z)
f_h = mh.mean() ; f_s = ms.mean()

# tableaux résultats (par niveau, moyennés sur l'état stationnaire)
Mc_up_h   = np.zeros(n_z) ; Mc_up_s   = np.zeros(n_z)   # M+  (updrafts, PONDÉRÉ par sigma)
Mc_dn_h   = np.zeros(n_z) ; Mc_dn_s   = np.zeros(n_z)   # M-  (downdrafts, pondéré)
Mc_net_h  = np.zeros(n_z) ; Mc_net_s  = np.zeros(n_z)   # rho0 * wbar_region
sigw_h    = np.zeros(n_z) ; sigw_s    = np.zeros(n_z)   # sigma_w(z) par région
frac_up_h = np.zeros(n_z) ; frac_up_s = np.zeros(n_z)   # fraction surfacique updraft sigma(z)

ds_w = xr.open_dataset(path3d('wa'))

for iz in range(n_z):
    acc_up_h = acc_up_s = 0.0
    acc_dn_h = acc_dn_s = 0.0
    acc_net_h = acc_net_s = 0.0
    acc_sw_h = acc_sw_s = 0.0
    acc_fr_h = acc_fr_s = 0.0
    n = 0

    for it in range(t_stat, n_t):
        w_2d = ds_w['wa'].isel({dim_t: it, dim_z: iz}).values
        w_h  = w_2d[mh] ; w_s = w_2d[ms]

        sw_h = w_h.std() ; sw_s = w_s.std()
        ws_h = max(W0_MIN, C_SIGMA * sw_h)
        ws_s = max(W0_MIN, C_SIGMA * sw_s)

        up_h = w_h >  ws_h ; dn_h = w_h < -ws_h
        up_s = w_s >  ws_s ; dn_s = w_s < -ws_s

        # flux de masse PONDÉRÉ : moyenne de (w * indicatrice) sur TOUTE la région
        #   <w·1_up>_rég = sigma · <w>_up   → flux de masse classique
        acc_up_h += (w_h * up_h).mean() ; acc_up_s += (w_s * up_s).mean()
        acc_dn_h += (w_h * dn_h).mean() ; acc_dn_s += (w_s * dn_s).mean()

        acc_net_h += w_h.mean() ; acc_net_s += w_s.mean()
        acc_sw_h  += sw_h       ; acc_sw_s  += sw_s
        acc_fr_h  += up_h.mean(); acc_fr_s  += up_s.mean()   # sigma(z)
        n += 1
        del w_2d, w_h, w_s, up_h, up_s, dn_h, dn_s
        gc.collect()

    Mc_up_h[iz]  = rho0[iz] * acc_up_h  / n
    Mc_up_s[iz]  = rho0[iz] * acc_up_s  / n
    Mc_dn_h[iz]  = rho0[iz] * acc_dn_h  / n
    Mc_dn_s[iz]  = rho0[iz] * acc_dn_s  / n
    Mc_net_h[iz] = rho0[iz] * acc_net_h / n
    Mc_net_s[iz] = rho0[iz] * acc_net_s / n
    sigw_h[iz]   = acc_sw_h / n ; sigw_s[iz] = acc_sw_s / n
    frac_up_h[iz]= acc_fr_h / n ; frac_up_s[iz] = acc_fr_s / n

    if iz % 10 == 0:
        print(f'  iz={iz}/{n_z-1}  ({alt[iz]:.0f} m)')

ds_w.close() ; del ds_w ; gc.collect()
print('Flux de masse Mc (pondéré par sigma) calculé par région.')
print(f'Fractions régionales : f_h={f_h:.3f}  f_s={f_s:.3f}')
# Out:
#   iz=0/73  (0 m)
#   iz=10/73  (1331 m)
#   iz=20/73  (6000 m)
#   iz=30/73  (11000 m)
#   iz=40/73  (16000 m)
#   iz=50/73  (21000 m)
#   iz=60/73  (26000 m)
#   iz=70/73  (31000 m)
# Flux de masse Mc (pondéré par sigma) calculé par région.
# Fractions régionales : f_h=0.423  f_s=0.577

# %% [markdown]
# ## §20.2 — Profils du flux de masse convectif
#
# Lecture attendue : $M^{+}$ positif (transport de masse vers le haut), maximal dans la
# basse/moyenne troposphère où la convection est active, surtout en région **humide**.
# $M_{\text{net}}\approx 0$ confirme la fermeture de masse (subsidence compensatoire).

# %%
scM = 1e3  # kg/m2/s -> 1e-3
idx18 = np.searchsorted(alt, 18000)

fig, axes = plt.subplots(1, 3, figsize=(16, 8), sharey=True)

# (a) M+ et M- par région
ax = axes[0]
ax.plot(Mc_up_h[:idx18]*scM, alt[:idx18], color='royalblue',   lw=2.5, label='M⁺ humide')
ax.plot(Mc_up_s[:idx18]*scM, alt[:idx18], color='saddlebrown', lw=2.5, label='M⁺ sèche')
ax.plot(Mc_dn_h[:idx18]*scM, alt[:idx18], color='royalblue',   lw=1.8, ls='--', label='M⁻ humide')
ax.plot(Mc_dn_s[:idx18]*scM, alt[:idx18], color='saddlebrown', lw=1.8, ls='--', label='M⁻ sèche')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel(r'$M^{\pm}$  (×10⁻³ kg m⁻² s⁻¹)')
ax.set_title('Updrafts / downdrafts (pondérés)', fontweight='bold')
ax.legend(fontsize=9) ; ax.grid(True, alpha=0.3)
ax.set_ylabel('Altitude (m)')

# (b) M_net par région + combinaison globale (test continuité)
ax = axes[1]
Mc_net_glob = f_h*Mc_net_h + f_s*Mc_net_s
ax.plot(Mc_net_h[:idx18]*scM, alt[:idx18], color='royalblue',   lw=2.5, label=r'humide ($>0$)')
ax.plot(Mc_net_s[:idx18]*scM, alt[:idx18], color='saddlebrown', lw=2.5, label=r'sèche ($<0$)')
ax.plot(Mc_net_glob[:idx18]*scM, alt[:idx18], color='black', lw=2, ls=':',
        label=r'$f_h M_h+f_s M_s$ ($\approx0$)')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel(r'$M_{net}=\rho_0\bar w$  (×10⁻³)')
ax.set_title('Flux net : circulation grande-échelle', fontweight='bold')
ax.legend(fontsize=8) ; ax.grid(True, alpha=0.3)

# (c) fraction updraft et sigma_w
ax = axes[2]
ax.plot(frac_up_h[:idx18]*100, alt[:idx18], color='royalblue',   lw=2.5, label='σ humide (%)')
ax.plot(frac_up_s[:idx18]*100, alt[:idx18], color='saddlebrown', lw=2.5, label='σ sèche (%)')
ax2 = ax.twiny()
ax2.plot(sigw_h[:idx18], alt[:idx18], color='seagreen', lw=1.5, ls=':', label=r'$\sigma_w$ humide')
ax2.set_xlabel(r'$\sigma_w$ (m/s)', color='seagreen')
ax.set_xlabel('Fraction updraft σ (%)')
ax.set_title('Couverture convective', fontweight='bold')
ax.legend(fontsize=8, loc='upper right') ; ax.grid(True, alpha=0.3)

plt.suptitle('§20 — Flux de masse convectif (pondéré σ) — état stationnaire',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# repères chiffrés
iz2  = np.argmin(np.abs(alt-2000))
print(f"M⁺ humide : max = {Mc_up_h[:idx18].max()*scM:.3f} ×10⁻³  à z={alt[np.argmax(Mc_up_h[:idx18])]:.0f} m")
print(f"M⁺ sèche  : max = {Mc_up_s[:idx18].max()*scM:.3f} ×10⁻³  à z={alt[np.argmax(Mc_up_s[:idx18])]:.0f} m")
print(f"M⁺/ρ₀ humide @~2km : {Mc_up_h[iz2]/rho0[iz2]*100:.2f} cm/s  (réf. Romps M/ρ ~1 cm/s)")
print()
print('── Test de continuité de masse (doit être ≈ 0) ──')
print(f"|f_h·M_net_h + f_s·M_net_s| moyen (0-18km) = "
      f"{np.abs(Mc_net_glob[:idx18]).mean()*scM:.4f} ×10⁻³ kg/m²/s")
print(f"|M_net_h| seul (humide) moyen              = "
      f"{np.abs(Mc_net_h[:idx18]).mean()*scM:.4f} ×10⁻³  (≠0 : circulation, NORMAL)")
# Out:
# M⁺ humide : max = 35.486 ×10⁻³  à z=843 m
# M⁺ sèche  : max = 22.994 ×10⁻³  à z=520 m
# M⁺/ρ₀ humide @~2km : 3.02 cm/s  (réf. Romps M/ρ ~1 cm/s)
#
# ── Test de continuité de masse (doit être ≈ 0) ──
# |f_h·M_net_h + f_s·M_net_s| moyen (0-18km) = 0.0000 ×10⁻³ kg/m²/s
# |M_net_h| seul (humide) moyen              = 2.6171 ×10⁻³  (≠0 : circulation, NORMAL)

# %% [markdown]
# - Activité verticale dominée par les régions humides
# - Montée humide, descente sèche
# - cla convection est faible en bas et tout en haut avec beaucoup d'updrafts faibles en regardant la valeur de sigma. Il y a moins d'updrafts au milieu mais plus intenses : la concentration à cet endroit maintient un M+ élevé.

# %% [markdown]
# ---
# # §21 — Vérification de l'identité flux de Reynolds ↔ flux de masse
#
# D'après l'éq. (2), dans l'approximation top-hat à deux panaches (updraft / environnement),
# le flux de moment vertical s'écrit exactement :
#
# $$
# \rho_0\,\overline{u'w'} \;=\; \rho_0\,\sigma(1-\sigma)\,(u_c-u_e)(w_c-w_e)
# \;\approx\; M_c\,(u_c - u_e),
# $$
#
# où $u_c,u_e$ sont les vents dans l'updraft et dans l'environnement, et
# $M_c=\rho_0\langle w\,\mathbb 1_{up}\rangle$ le flux de masse pondéré (§20.1).

# %%
# ── u_c (updraft), u_e (environnement) par niveau et région ──────────
uc_h = np.zeros(n_z) ; uc_s = np.zeros(n_z)   # vent dans cœurs convectifs
ue_h = np.zeros(n_z) ; ue_s = np.zeros(n_z)   # vent dans l'environnement
ubar_h = np.zeros(n_z) ; ubar_s = np.zeros(n_z)  # vent moyen région (diagnostic)

ds_u = xr.open_dataset(path3d('ua'))
ds_w = xr.open_dataset(path3d('wa'))

for iz in range(n_z):
    acc_uc_h = acc_uc_s = 0.0
    acc_ue_h = acc_ue_s = 0.0
    acc_ub_h = acc_ub_s = 0.0
    n = 0
    for it in range(t_stat, n_t):
        u_2d = ds_u['ua'].isel({dim_t: it, dim_z: iz}).values
        w_2d = ds_w['wa'].isel({dim_t: it, dim_z: iz}).values

        for mask, ref in [(mh, 'h'), (ms, 's')]:
            u_r = u_2d[mask] ; w_r = w_2d[mask]
            ws  = max(W0_MIN, C_SIGMA * w_r.std())
            up  = w_r > ws
            # u_c : moyenne sur updrafts ; u_e : moyenne sur le reste (environnement)
            uc_val = u_r[up].mean()  if up.any()      else u_r.mean()
            ue_val = u_r[~up].mean() if (~up).any()   else u_r.mean()
            if ref == 'h':
                acc_uc_h += uc_val ; acc_ue_h += ue_val ; acc_ub_h += u_r.mean()
            else:
                acc_uc_s += uc_val ; acc_ue_s += ue_val ; acc_ub_s += u_r.mean()
        n += 1
        del u_2d, w_2d
        gc.collect()

    uc_h[iz] = acc_uc_h/n ; uc_s[iz] = acc_uc_s/n
    ue_h[iz] = acc_ue_h/n ; ue_s[iz] = acc_ue_s/n
    ubar_h[iz] = acc_ub_h/n ; ubar_s[iz] = acc_ub_s/n

    if iz % 10 == 0:
        print(f'  iz={iz}/{n_z-1}  ({alt[iz]:.0f} m)')

ds_u.close() ; ds_w.close() ; del ds_u, ds_w ; gc.collect()

# contraste correct et flux de masse reconstruit
duc_h = uc_h - ue_h ; duc_s = uc_s - ue_s
Phi_masse_h = Mc_up_h * duc_h
Phi_masse_s = Mc_up_s * duc_s
print("u_c, u_e et Φ_masse = M_c·(u_c - u_e) calculés.")
# Out:
#   iz=0/73  (0 m)
#   iz=10/73  (1331 m)
#   iz=20/73  (6000 m)
#   iz=30/73  (11000 m)
#   iz=40/73  (16000 m)
#   iz=50/73  (21000 m)
#   iz=60/73  (26000 m)
#   iz=70/73  (31000 m)
# u_c, u_e et Φ_masse = M_c·(u_c - u_e) calculés.

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 8), sharey=True)
sl = slice(None, idx_tropo)

# (a) contraste de vent u_c - u_e
ax = axes[0]
ax.plot(duc_h[sl], alt[sl], color='royalblue',   lw=2.5, label='humide')
ax.plot(duc_s[sl], alt[sl], color='saddlebrown', lw=2.5, label='sèche')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel(r'$u_c - u_e$  (m/s)')
ax.set_title('Contraste vent cœur / environnement', fontweight='bold')
ax.legend(fontsize=9) ; ax.grid(True, alpha=0.3)
ax.set_ylabel('Altitude (m)')

# (b) humide : Reynolds vs masse
ax = axes[1]
ax.plot(flux_glob_h[sl]*sc, alt[sl], color='royalblue', lw=2.5, label=r"$\rho_0\overline{u'w'}$ (Reynolds)")
ax.plot(Phi_masse_h[sl]*sc, alt[sl], color='red', lw=2, ls='--', label=r'$M_c(u_c-u_e)$ (masse)')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel(r'flux  (×10⁻³ kg m⁻² s⁻²)')
ax.set_title('HUMIDE — Reynolds vs masse', fontweight='bold')
ax.legend(fontsize=8) ; ax.grid(True, alpha=0.3)

# (c) sèche
ax = axes[2]
ax.plot(flux_glob_s[sl]*sc, alt[sl], color='saddlebrown', lw=2.5, label=r"$\rho_0\overline{u'w'}$ (Reynolds)")
ax.plot(Phi_masse_s[sl]*sc, alt[sl], color='red', lw=2, ls='--', label=r'$M_c(u_c-u_e)$ (masse)')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel(r'flux  (×10⁻³ kg m⁻² s⁻²)')
ax.set_title('SÈCHE — Reynolds vs masse', fontweight='bold')
ax.legend(fontsize=8) ; ax.grid(True, alpha=0.3)

plt.suptitle(r'§21 — Identité bulk-plume : $\rho_0\overline{uw}\approx M_c(u_c-u_e)$',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

for tag, fr, fm in [('HUMIDE', flux_glob_h, Phi_masse_h), ('SÈCHE', flux_glob_s, Phi_masse_s)]:
    a = fr[:idx_tropo] ; b = fm[:idx_tropo]
    ok = np.isfinite(a) & np.isfinite(b)
    r  = np.corrcoef(a[ok], b[ok])[0,1]
    pente = (a[ok]@b[ok])/(b[ok]@b[ok]) if (b[ok]@b[ok])!=0 else np.nan
    print(f'{tag:7s}: corr(Reynolds, masse) = {r:+.3f}   pente (Reynolds/masse) = {pente:+.3f}')
# Out:
# HUMIDE : corr(Reynolds, masse) = +0.899   pente (Reynolds/masse) = +1.943
# SÈCHE  : corr(Reynolds, masse) = +0.731   pente (Reynolds/masse) = +0.774

# %% [markdown]
# ---
# # §22 — Test de l'équation bulk-plume (1) : $\partial_z M = (\varepsilon-\delta)M$
#
# L'éq. (1) définit le taux net d'entraînement/détraînement à partir du seul profil de
# flux de masse :
#
# $$
# (\varepsilon-\delta)(z) \;=\; \frac{1}{M_c}\,\partial_z M_c .
# $$
#
# - $(\varepsilon-\delta)>0$ : couche **d'entraînement** net (le flux de masse croît avec $z$, typiquement en basse troposphère) ;
# - $(\varepsilon-\delta)<0$ : couche de **détraînement** net (sommet convectif, le flux décroît).
#
# On compare aussi à l'ordre de grandeur de Romps ($\varepsilon\sim 0.4$–$1.5$ km⁻¹).
# On masque les niveaux où $|M_c|$ est trop faible (division instable).

# %%
def eps_minus_delta(M, z, seuil_rel=0.05):
    """(eps - delta) = dz(M)/M, en km^-1, masqué où |M| < seuil_rel*max|M|."""
    M    = np.asarray(M, float)
    dMdz = np.gradient(M, z)              # s^-1 * (kg/m2/s)/m -> par mètre
    seuil = seuil_rel * np.nanmax(np.abs(M))
    ed = np.where(np.abs(M) > seuil, dMdz / M, np.nan)
    return ed * 1000.0                    # m^-1 -> km^-1

ed_h = eps_minus_delta(Mc_up_h, alt)
ed_s = eps_minus_delta(Mc_up_s, alt)

fig, axes = plt.subplots(1, 2, figsize=(13, 8), sharey=True)

ax = axes[0]
ax.plot(Mc_up_h[:idx18]*scM, alt[:idx18], color='royalblue',   lw=2.5, label='humide')
ax.plot(Mc_up_s[:idx18]*scM, alt[:idx18], color='saddlebrown', lw=2.5, label='sèche')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel(r'$M_c$  (×10⁻³ kg m⁻² s⁻¹)')
ax.set_title(r'Flux de masse $M_c$', fontweight='bold')
ax.legend(fontsize=9) ; ax.grid(True, alpha=0.3)
ax.set_ylabel('Altitude (m)')

ax = axes[1]
ax.plot(ed_h[:idx18], alt[:idx18], color='royalblue',   lw=2.5, label='humide')
ax.plot(ed_s[:idx18], alt[:idx18], color='saddlebrown', lw=2.5, label='sèche')
ax.axvline(0, color='grey', alpha=0.4)
for v in (0.4, 1.5):
    ax.axvline(v, color='green', alpha=0.3, ls=':')
    ax.axvline(-v, color='red', alpha=0.3, ls=':')
ax.set_xlabel(r'$(\varepsilon-\delta)$  (km⁻¹)')
ax.set_title(r'$\partial_z M_c / M_c$  (vert: entraîn., réf. ±0.4/1.5)', fontweight='bold')
ax.set_xlim(-3, 3)
ax.legend(fontsize=9) ; ax.grid(True, alpha=0.3)

plt.suptitle(r'§22 — Éq. (1) bulk-plume : taux net $(\varepsilon-\delta)=\partial_z M_c/M_c$',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# niveau de transition entraînement -> détraînement (humide)
sub = np.where(np.isfinite(ed_h[:idx18]))[0]
if sub.size:
    sign_change = np.where(np.diff(np.sign(ed_h[sub])) < 0)[0]
    if sign_change.size:
        iz_c = sub[sign_change[0]]
        print(f'Région humide : entraînement→détraînement vers z ≈ {alt[iz_c]:.0f} m')
    print(f'(ε-δ) humide médian basse tropo (0-6km) : '
          f'{np.nanmedian(ed_h[:np.searchsorted(alt,6000)]):+.2f} km⁻¹')
# Out:
# /tmp/ipykernel_5723/2804432853.py:6: RuntimeWarning: divide by zero encountered in divide
#   ed = np.where(np.abs(M) > seuil, dMdz / M, np.nan)
# Région humide : entraînement→détraînement vers z ≈ 667 m
# (ε-δ) humide médian basse tropo (0-6km) : -0.04 km⁻¹

# %% [markdown]
# ---
# # §23 — Bouclage du budget de quantité de mouvement
#
# Dernier test de cohérence : la tendance de vent moyen donnée par la ivergence du flux
# de Reynold (déjà utilisée en §16/§18) doit être reproduite par la divergence du flux
# de masse:
#
# $$
# \partial_t \bar u
# \;=\; -\frac{1}{\rho_0}\,\partial_z\!\big(\rho_0\,\overline{u'w'}\big)
# \;\approx\; -\frac{1}{\rho_0}\,\partial_z\!\big[M_c(\bar u - u_c)\big].
# $$

# %%
def tendance(flux_profil):
    """Force de Reynolds : -1/rho0 · d(rho0 <u'w'>)/dz  (m/s²)."""
    return -np.gradient(flux_profil, alt) / rho0

tend_rey_h  = tendance(flux_glob_h)
tend_rey_s  = tendance(flux_glob_s)
tend_mass_h = tendance(Phi_masse_h)
tend_mass_s = tendance(Phi_masse_s)

fig, axes = plt.subplots(1, 2, figsize=(13, 9), sharey=True)
sl = slice(None, idx_tropo)
st = 1e5  # m/s² -> 1e-5

ax = axes[0]
ax.plot(tend_rey_h[sl]*st,  alt[sl], color='royalblue', lw=2.5, label='Reynolds (vérité)')
ax.plot(tend_mass_h[sl]*st, alt[sl], color='red', lw=2, ls='--', label='flux de masse')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel(r'$\partial_t\bar u$  (×10⁻⁵ m/s²)')
ax.set_title('HUMIDE', fontweight='bold')
ax.legend(fontsize=9) ; ax.grid(True, alpha=0.3)
ax.set_ylabel('Altitude (m)')

ax = axes[1]
ax.plot(tend_rey_s[sl]*st,  alt[sl], color='saddlebrown', lw=2.5, label='Reynolds (vérité)')
ax.plot(tend_mass_s[sl]*st, alt[sl], color='red', lw=2, ls='--', label='flux de masse')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel(r'$\partial_t\bar u$  (×10⁻⁵ m/s²)')
ax.set_title('SÈCHE', fontweight='bold')
ax.legend(fontsize=9) ; ax.grid(True, alpha=0.3)

plt.suptitle(r'§24 — Budget QDM : $-\frac{1}{\rho_0}\partial_z(\rho_0\overline{uw})$ '
             r'vs $-\frac{1}{\rho_0}\partial_z[M_c(\bar u-u_c)]$',
             fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

for tag, tr, tm in [('HUMIDE', tend_rey_h, tend_mass_h), ('SÈCHE', tend_rey_s, tend_mass_s)]:
    a = tr[:idx_tropo] ; b = tm[:idx_tropo]
    ok = np.isfinite(a) & np.isfinite(b)
    r  = np.corrcoef(a[ok], b[ok])[0,1]
    rms= np.sqrt(np.mean((a[ok]-b[ok])**2))
    print(f'{tag:7s}: corr = {r:+.3f}   RMS écart = {rms*st:.3f} ×10⁻⁵ m/s²')
# Out:
# HUMIDE : corr = +0.909   RMS écart = 1.429 ×10⁻⁵ m/s²
# SÈCHE  : corr = +0.734   RMS écart = 0.315 ×10⁻⁵ m/s²

# %%
# ============================================================================
# S26 — Sensibilite au seuil + SELECTION du meilleur seuil
#   Pour chaque (W0,C) : seuil ws(z)=max(W0, C*sigma_w(z)).
#   On recalcule Mc, Du=u_c-u_e, Phi=Mc*Du, puis on confronte au Reynolds verite.
#   Meilleur seuil = celui qui minimise |pente_humide - 1| (identite la plus fidele).
# ============================================================================

iz_lo = int(np.searchsorted(alt, 2000))
iz_hi = int(np.searchsorted(alt, 18000))
disp  = slice(iz_lo, iz_hi)

seuils = [(0.0, 0.5), (0.0, 1.0), (0.0, 1.5), (0.0, 2.0),
          (0.5, 1.0), (1.0, 1.0), (0.25, 0.75)]

def diag_flux_masse(W0, C, region_mask):
    """Recalcule (Mc, Du, Phi, sigma) profils pleine colonne pour un seuil donne."""
    Mc  = np.zeros(n_z); duc = np.zeros(n_z); sig = np.zeros(n_z)
    ds_u = xr.open_dataset(path3d('ua'))
    ds_w = xr.open_dataset(path3d('wa'))
    for iz in range(n_z):
        a_mc = a_uc = a_ue = a_sg = 0.0; n = 0
        for it in range(t_stat, n_t):
            u_r = ds_u['ua'].isel({dim_t: it, dim_z: iz}).values[region_mask]
            w_r = ds_w['wa'].isel({dim_t: it, dim_z: iz}).values[region_mask]
            ws  = max(W0, C * w_r.std())
            up  = w_r > ws
            a_mc += (w_r * up).mean()
            a_uc += u_r[up].mean()  if up.any()    else u_r.mean()
            a_ue += u_r[~up].mean() if (~up).any() else u_r.mean()
            a_sg += up.mean()
            n += 1
            del u_r, w_r, up
        Mc[iz]  = rho0[iz] * a_mc / n
        duc[iz] = (a_uc - a_ue) / n
        sig[iz] = a_sg / n
        gc.collect()
    ds_u.close(); ds_w.close(); del ds_u, ds_w; gc.collect()
    return Mc, duc, Mc * duc, sig

res_seuil = {}
for (W0, C) in seuils:
    print('seuil W0=' + str(W0) + ' C=' + str(C) + ' ...', end=' ', flush=True)
    d = {}
    for tag, mask, fr in [('h', mh, flux_glob_h), ('s', ms, flux_glob_s)]:
        Mc, duc, Phi, sig = diag_flux_masse(W0, C, mask)
        a = fr[disp]; b = Phi[disp]
        ok = np.isfinite(a) & np.isfinite(b)
        r     = np.corrcoef(a[ok], b[ok])[0, 1]
        pente = (a[ok] @ b[ok]) / (b[ok] @ b[ok]) if (b[ok] @ b[ok]) != 0 else np.nan
        d[tag] = dict(Mc=Mc, duc=duc, Phi=Phi, sig=sig, r=r, pente=pente)
    res_seuil[(W0, C)] = d
    print('corr_h=' + format(d['h']['r'], '+.3f')
          + ' pente_h=' + format(d['h']['pente'], '+.2f')
          + ' | corr_s=' + format(d['s']['r'], '+.3f')
          + ' pente_s=' + format(d['s']['pente'], '+.2f'))

# --- SELECTION du meilleur seuil : pente humide la plus proche de 1 ---
def score(k):
    p = res_seuil[k]['h']['pente']
    return abs(p - 1.0) if np.isfinite(p) else np.inf

best = min(seuils, key=score)
W0_BEST, C_BEST = best
print()
print('>>> MEILLEUR SEUIL : W0=' + str(W0_BEST) + '  C=' + str(C_BEST)
      + '  (pente_h=' + format(res_seuil[best]['h']['pente'], '+.3f')
      + ', corr_h=' + format(res_seuil[best]['h']['r'], '+.3f') + ')')

# --- on FIGE les profils du meilleur seuil pour tout le reste (S27-S29) ---
Mc_up_h   = res_seuil[best]['h']['Mc'].copy()
Mc_up_s   = res_seuil[best]['s']['Mc'].copy()
duc_h     = res_seuil[best]['h']['duc'].copy()
duc_s     = res_seuil[best]['s']['duc'].copy()
Phi_masse_h = res_seuil[best]['h']['Phi'].copy()
Phi_masse_s = res_seuil[best]['s']['Phi'].copy()
sig_h     = res_seuil[best]['h']['sig'].copy()
sig_s     = res_seuil[best]['s']['sig'].copy()
print('Mc_up_*, duc_*, Phi_masse_* recalcules avec le meilleur seuil.')
# Out:
# seuil W0=0.0 C=0.5 ... corr_h=+0.866 pente_h=+2.17 | corr_s=+0.889 pente_s=+1.41
# seuil W0=0.0 C=1.0 ... corr_h=+0.895 pente_h=+2.21 | corr_s=+0.844 pente_s=+1.42
# seuil W0=0.0 C=1.5 ... corr_h=+0.922 pente_h=+2.40 | corr_s=+0.823 pente_s=+1.63
# seuil W0=0.0 C=2.0 ... corr_h=+0.944 pente_h=+2.58 | corr_s=+0.810 pente_s=+2.11
# seuil W0=0.5 C=1.0 ... corr_h=+0.943 pente_h=+2.48 | corr_s=+0.755 pente_s=+14.91
# seuil W0=1.0 C=1.0 ... corr_h=+0.982 pente_h=+2.96 | corr_s=+0.545 pente_s=+101.43
# seuil W0=0.25 C=0.75 ... corr_h=+0.899 pente_h=+2.20 | corr_s=+0.788 pente_s=+5.15
#
# >>> MEILLEUR SEUIL : W0=0.0  C=0.5  (pente_h=+2.165, corr_h=+0.866)
# Mc_up_*, duc_*, Phi_masse_* recalcules avec le meilleur seuil.

# %%
# ----------------------------------------------------------------------------
# S26b — Visualisation : pente et correlation vs seuil ; le best surligne
# ----------------------------------------------------------------------------
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
labels = [str(W0) + '/' + str(C) for (W0, C) in seuils]
x = np.arange(len(seuils))
ibest = seuils.index(best)

ax = axes[0]
ax.plot(x, [res_seuil[k]['h']['pente'] for k in seuils], 'o-', color='royalblue', label='humide')
ax.plot(x, [res_seuil[k]['s']['pente'] for k in seuils], 's-', color='saddlebrown', label='seche')
ax.axhline(1.0, color='green', ls=':', label='pente ideale = 1')
ax.scatter([ibest], [res_seuil[best]['h']['pente']], s=160, facecolors='none',
           edgecolors='red', linewidths=2, zorder=5, label='best')
ax.set_xticks(x); ax.set_xticklabels(labels, rotation=45, fontsize=8)
ax.set_ylabel('pente (Reynolds / masse)'); ax.set_xlabel('seuil W0/C')
ax.set_title('Pente vs seuil', fontweight='bold'); ax.legend(fontsize=8); ax.grid(alpha=0.3)

ax = axes[1]
ax.plot(x, [res_seuil[k]['h']['r'] for k in seuils], 'o-', color='royalblue', label='humide')
ax.plot(x, [res_seuil[k]['s']['r'] for k in seuils], 's-', color='saddlebrown', label='seche')
ax.scatter([ibest], [res_seuil[best]['h']['r']], s=160, facecolors='none',
           edgecolors='red', linewidths=2, zorder=5, label='best')
ax.set_xticks(x); ax.set_xticklabels(labels, rotation=45, fontsize=8)
ax.set_ylabel('correlation'); ax.set_xlabel('seuil W0/C')
ax.set_title('Correlation vs seuil', fontweight='bold'); ax.set_ylim(0, 1.02)
ax.legend(fontsize=8); ax.grid(alpha=0.3)

ax = axes[2]
for tag, col, mk in [('h', 'royalblue', 'o'), ('s', 'saddlebrown', 's')]:
    sigm = [np.nanmean(res_seuil[k][tag]['sig'][disp]) for k in seuils]
    pent = [res_seuil[k][tag]['pente'] for k in seuils]
    ax.scatter(sigm, pent, color=col, marker=mk, s=60,
               label='humide' if tag == 'h' else 'seche')
ax.axhline(1.0, color='green', ls=':')
ax.set_xlabel('sigma updraft moyen (2-18 km)'); ax.set_ylabel('pente')
ax.set_title('Pente vs fraction sigma', fontweight='bold'); ax.legend(fontsize=8); ax.grid(alpha=0.3)

plt.suptitle('S26 - Selection du seuil  (best = W0=' + str(W0_BEST) + ' C=' + str(C_BEST) + ')',
             fontsize=13, fontweight='bold')
plt.tight_layout(); plt.show()

# %%
# ============================================================================
# S27 — Decomposition de la divergence du flux de masse (MEILLEUR SEUIL S26)
#   d/dz[Mc·Du] = (dMc/dz)·Du  +  Mc·(dDu/dz)     avec Du = u_c - u_e
#   (CALCULS pleine colonne ; AFFICHAGE 2000-18000 m ; zone humide)
# ============================================================================

st = 1e5  # m/s^2 -> 1e-5

def decompose_div(Mc, duc):
    dMc  = np.gradient(Mc,  alt)
    dduc = np.gradient(duc, alt)
    A = dMc * duc
    B = Mc * dduc
    tot = A + B
    return A, B, tot, -tot / rho0

A_h, B_h, div_h, tend_h = decompose_div(Mc_up_h, duc_h)
A_s, B_s, div_s, tend_s = decompose_div(Mc_up_s, duc_s)   # calcul conserve

tend_rey_h = -np.gradient(flux_glob_h, alt) / rho0
tend_rey_s = -np.gradient(flux_glob_s, alt) / rho0        # calcul conserve

fig, axes = plt.subplots(1, 2, figsize=(14, 8), sharey=True)

ax = axes[0]
ax.plot(A_h[disp]*sc,   alt[disp], color='darkorange', lw=2.2, label='A = (dMc/dz) Du')
ax.plot(B_h[disp]*sc,   alt[disp], color='purple',     lw=2.2, label='B = Mc (dDu/dz)')
ax.plot(div_h[disp]*sc, alt[disp], color='black', lw=2.5, ls='--', label='A + B')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel('dPhi/dz  (x1e-3)')
ax.set_title('HUMIDE - decomposition divergence', fontweight='bold')
ax.legend(fontsize=9); ax.grid(alpha=0.3)
ax.set_ylabel('Altitude (m)'); ax.set_ylim(2000, 18000)

ax = axes[1]
ax.plot(tend_rey_h[disp]*st, alt[disp], color='royalblue', lw=2.5, label='Reynolds (verite)')
ax.plot(tend_h[disp]*st,     alt[disp], color='red', lw=2, ls='--', label='masse -1/rho0 (A+B)')
ax.plot((-A_h[disp]/rho0[disp])*st, alt[disp], color='darkorange', lw=1.3, ls=':', label='part A')
ax.plot((-B_h[disp]/rho0[disp])*st, alt[disp], color='purple',     lw=1.3, ls=':', label='part B')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel('d(ubar)/dt  (x1e-5 m/s2)')
ax.set_title('HUMIDE - tendance vent', fontweight='bold')
ax.legend(fontsize=8); ax.grid(alpha=0.3); ax.set_ylim(2000, 18000)

plt.suptitle('S27 - decomposition divergence  [best seuil, humide, 2-18 km]',
             fontsize=13, fontweight='bold')
plt.tight_layout(); plt.show()

print('-- Poids relatif des termes A et B (norme L2, 2-18 km) --')
for tag, A, B in [('HUMIDE', A_h, B_h), ('SECHE', A_s, B_s)]:
    nA = np.sqrt(np.nansum(A[disp]**2)); nB = np.sqrt(np.nansum(B[disp]**2))
    print(tag.ljust(7) + ': ||A||=' + format(nA*sc, '7.3f')
          + '  ||B||=' + format(nB*sc, '7.3f')
          + '  -> A domine a ' + format(100*nA/(nA+nB), '4.1f') + '%')
# Out:
# -- Poids relatif des termes A et B (norme L2, 2-18 km) --
# HUMIDE : ||A||=  0.006  ||B||=  0.014  -> A domine a 30.8%
# SECHE  : ||A||=  0.001  ||B||=  0.003  -> A domine a 16.0%

# %%
## ============================================================================
# S28 — Tout exprimer en fonction de Du = u_c - u_e (MEILLEUR SEUIL S26)
#   dMc/dz = (eps-delta) Mc  ->  d/dz(Mc Du) = Mc [(eps-delta) Du + dDu/dz]
#   (CALCULS pleine colonne ; AFFICHAGE 2000-18000 m ; zone humide)
# ============================================================================

def eps_delta_si(M, seuil_rel=0.05):
    dMdz = np.gradient(M, alt)
    seuil = seuil_rel * np.nanmax(np.abs(M))
    return np.where(np.abs(M) > seuil, dMdz / M, np.nan)

edh = eps_delta_si(Mc_up_h)
eds = eps_delta_si(Mc_up_s)   # calcul conserve

div_re_h = Mc_up_h * (edh*duc_h + np.gradient(duc_h, alt))
div_re_s = Mc_up_s * (eds*duc_s + np.gradient(duc_s, alt))   # calcul conserve

print('-- Sanity check : reecriture (eps-delta) vs derivee directe (2-18 km) --')
for tag, d1, d2 in [('HUMIDE', div_h, div_re_h), ('SECHE', div_s, div_re_s)]:
    aa = d1[disp]; bb = d2[disp]
    ok = np.isfinite(aa) & np.isfinite(bb)
    err = np.sqrt(np.nanmean((aa[ok] - bb[ok])**2))
    print(tag.ljust(7) + ': RMS ecart = ' + format(err*sc, '.4e') + ' x1e-3  (≈0 attendu)')

fig, axes = plt.subplots(1, 3, figsize=(16, 6), sharey=True)

ax = axes[0]
ax.plot(duc_h[disp], alt[disp], color='royalblue', lw=2.5, label='Du = u_c - u_e')
ax.plot((ubar_h-uc_h)[disp], alt[disp], color='royalblue', lw=1.3, ls=':', label='ubar - u_c')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel('m/s'); ax.set_title('HUMIDE - contrastes de vent', fontweight='bold')
ax.legend(fontsize=8); ax.grid(alpha=0.3)
ax.set_ylabel('Altitude (m)'); ax.set_ylim(2000, 18000)

ax = axes[1]
ax.plot(np.gradient(duc_h, alt)[disp]*1e3, alt[disp], color='royalblue', lw=2.5, label='humide')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel('dDu/dz  (x1e-3 s-1)')
ax.set_title('HUMIDE - cisaillement du contraste', fontweight='bold')
ax.legend(fontsize=9); ax.grid(alpha=0.3); ax.set_ylim(2000, 18000)

ax = axes[2]
ax.plot(edh[disp]*1000, alt[disp], color='royalblue', lw=2.5, label='humide')
ax.axvline(0, color='grey', alpha=0.4); ax.set_xlim(-3, 3)
ax.set_xlabel('(eps-delta)  (km-1)')
ax.set_title('HUMIDE - entrainement net', fontweight='bold')
ax.legend(fontsize=9); ax.grid(alpha=0.3); ax.set_ylim(2000, 18000)

plt.suptitle('S28 - Mc [(eps-delta) Du + dDu/dz]  [best seuil, humide, 2-18 km]',
             fontsize=13, fontweight='bold')
plt.tight_layout(); plt.show()

print()
print('-- Caracterisation de Du (2-18 km) --')
for tag, duc in [('HUMIDE', duc_h), ('SECHE', duc_s)]:
    d = duc[disp]; ok = np.isfinite(d); z = alt[disp][ok]
    pente, ordo = np.polyfit(z, d[ok], 1)
    print(tag.ljust(7) + ': <Du>=' + format(np.nanmean(d), '+.3f')
          + ' m/s  sig(Du)=' + format(np.nanstd(d), '.3f')
          + '  dDu/dz(lin)=' + format(pente*1e3, '+.4f') + 'x1e-3 s-1'
          + '  ratio sig/|moy|=' + format(np.nanstd(d)/abs(np.nanmean(d)), '.2f'))
# Out:
# -- Sanity check : reecriture (eps-delta) vs derivee directe (2-18 km) --
# HUMIDE : RMS ecart = 2.7817e-19 x1e-3  (≈0 attendu)
# SECHE  : RMS ecart = 5.1538e-20 x1e-3  (≈0 attendu)
# -- Caracterisation de Du (2-18 km) --
# HUMIDE : <Du>=-0.347 m/s  sig(Du)=0.198  dDu/dz(lin)=+0.0328x1e-3 s-1  ratio sig/|moy|=0.57
# SECHE  : <Du>=-0.103 m/s  sig(Du)=0.117  dDu/dz(lin)=-0.0051x1e-3 s-1  ratio sig/|moy|=1.14

# %%
 #============================================================================
# S30 — Lien eq. momentum panache <-> budget  (VERSION ROBUSTE)
#   Eq.1 : dz(u_c) = eps (u_e - u_c)
#   Eq.2 : dz(Mc Du) = Mc[-delta Du - dz(u_e)]   (apres injection eq.1), Du=u_c-u_e
#   uc/ue RECALCULES au meilleur seuil (W0_BEST, C_BEST) de S26.
# ============================================================================

# --- 0) recalcul de u_c, u_e au MEILLEUR seuil (coherent avec Mc_up_*, duc_*) ---
uc_h = np.full(n_z, np.nan); ue_h = np.full(n_z, np.nan)
ds_u = xr.open_dataset(path3d('ua'))
ds_w = xr.open_dataset(path3d('wa'))
for iz in range(n_z):
    a_uc = a_ue = 0.0; n = 0
    for it in range(t_stat, n_t):
        u_r = ds_u['ua'].isel({dim_t: it, dim_z: iz}).values[mh]
        w_r = ds_w['wa'].isel({dim_t: it, dim_z: iz}).values[mh]
        ws  = max(W0_BEST, C_BEST * w_r.std())
        up  = w_r > ws
        a_uc += u_r[up].mean()  if up.any()    else u_r.mean()
        a_ue += u_r[~up].mean() if (~up).any() else u_r.mean()
        n += 1
        del u_r, w_r, up
    uc_h[iz] = a_uc / n; ue_h[iz] = a_ue / n
    gc.collect()
ds_u.close(); ds_w.close(); del ds_u, ds_w; gc.collect()
print('u_c, u_e recalcules au seuil best (W0=' + str(W0_BEST) + ', C=' + str(C_BEST) + ').')

duc_h_loc = uc_h - ue_h          # u_c - u_e
uec_h     = ue_h - uc_h          # u_e - u_c
dz_uc_h   = np.gradient(uc_h, alt)
dz_ue_h   = np.gradient(ue_h, alt)

# --- masque "flux de masse significatif" : Mc > 5% du max, pour tout l'affichage ---
Mc_seuil = 0.05 * np.nanmax(np.abs(Mc_up_h))
valid    = np.abs(Mc_up_h) > Mc_seuil          # bool plein colonne
# borne haute effective : dernier niveau valide sous 18 km
iz_top_valid = np.where(valid[:iz_hi])[0]
iz_top = iz_top_valid.max() if iz_top_valid.size else iz_hi
print('niveau max ou Mc significatif : z = ' + format(alt[iz_top], '.0f') + ' m')

# --- 1) Test eq.1 : regression dz(u_c) = eps (u_e - u_c) sur 2km - iz_top ---
fenz = np.zeros(n_z, bool); fenz[iz_lo:iz_top+1] = True
m1 = fenz & np.isfinite(uec_h) & np.isfinite(dz_uc_h)
x = uec_h[m1]; y = dz_uc_h[m1]
eps_glob_h = (x @ y) / (x @ x) if (x @ x) != 0 else np.nan
r_eq1 = np.corrcoef(x, y)[0, 1] if x.size > 2 else np.nan
print('-- Eq.1 dz(u_c)=eps(u_e-u_c) -- eps=' + format(eps_glob_h*1000, '+.4f')
      + ' km-1  corr=' + format(r_eq1, '+.3f') + '  (n=' + str(x.size) + ' pts)')

# --- 2) (eps-delta) du flux de masse -> delta ---
def eps_delta_si(M, seuil_rel=0.05):
    dMdz = np.gradient(M, alt)
    s = seuil_rel * np.nanmax(np.abs(M))
    return np.where(np.abs(M) > s, dMdz / M, np.nan)
emd_h   = eps_delta_si(Mc_up_h)
delta_h = eps_glob_h - emd_h

# --- 3) coherence budget direct vs reecrit via eq.1 ---
div_direct_h = np.gradient(Mc_up_h * duc_h_loc, alt)
div_eq1_h    = Mc_up_h * (-delta_h * duc_h_loc - dz_ue_h)
m3 = fenz & np.isfinite(div_direct_h) & np.isfinite(div_eq1_h)
rms_re  = np.sqrt(np.nanmean((div_direct_h[m3] - div_eq1_h[m3])**2))
corr_re = np.corrcoef(div_direct_h[m3], div_eq1_h[m3])[0, 1] if m3.sum() > 2 else np.nan
print('-- Reecriture budget via eq.1 -- corr=' + format(corr_re, '+.3f')
      + '  RMS=' + format(rms_re*sc, '.4e') + ' x1e-3')

# ----------------------------------------------------------------------------
# Figures : on n'affiche QUE les niveaux valides (Mc significatif)
# ----------------------------------------------------------------------------
zb = alt[iz_lo:iz_top+1]          # axe vertical borne
sb = slice(iz_lo, iz_top+1)

fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# (b) contrastes
ax = axes[0]
ax.plot(duc_h_loc[sb], zb, color='royalblue', lw=2.5, label='u_c - u_e')
ax.plot(uec_h[sb],     zb, color='crimson',   lw=2.0, ls='--', label='u_e - u_c')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel('m/s'); ax.set_title('Contrastes', fontweight='bold')
ax.legend(fontsize=9); ax.grid(alpha=0.3); ax.set_ylabel('Altitude (m)')

# (c) divergences : seulement sur niveaux valides -> plus de decrochage
ax = axes[1]
dd = np.where(valid, div_direct_h, np.nan)[sb]
de = np.where(valid, div_eq1_h,    np.nan)[sb]
ax.plot(dd*sc, zb, color='black',  lw=2.5, label='dz(Mc Du) direct')
ax.plot(de*sc, zb, color='orange', lw=2, ls='--', label='Mc[-delta Du - dz u_e]')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel('dPhi/dz  (x1e-3)'); ax.set_title('Budget direct vs eq.1', fontweight='bold')
ax.legend(fontsize=8); ax.grid(alpha=0.3)

plt.suptitle('S30 - eq.1 panache <-> budget  [humide, 2km - '
             + format(alt[iz_top]/1000, '.0f') + 'km, Mc significatif]',
             fontsize=12, fontweight='bold')
plt.tight_layout(); plt.show()
# Out:
# u_c, u_e recalcules au seuil best (W0=0.0, C=0.5).
# niveau max ou Mc significatif : z = 17500 m
# -- Eq.1 dz(u_c)=eps(u_e-u_c) -- eps=-0.3164 km-1  corr=-0.651  (n=32 pts)
# -- Reecriture budget via eq.1 -- corr=+0.716  RMS=5.0994e-03 x1e-3

# %%
# ============================================================================
# S31 — Test Romps (2014) : amplitude du flux de Reynolds proportionnelle a M_c/rho0
#   Phi_rey(z) = rho0 <u'w'>  ;  Romps : |Phi_rey| ~ M_c * |Du|  (deja vu)
#   Ici on teste la forme LOCALE  Phi_rey(z) ≈ k * (M_c/rho0)(z) * echelle_vent
#   et la proportionnalite de l'AMPLITUDE globale A vs flux de masse integre.
# ============================================================================

z_c = alt[iz_top]                       # sommet utile (Mc significatif)
sl_fit = slice(iz_lo, iz_top+1)
zf = alt[sl_fit].astype(float)

# 1) amplitude A(z) du flux de Reynolds : on enleve la forme adimensionnee xi(1-xi)^n
#    en reutilisant le fit polynomial deja realise (A_h, zc_h, n_h en S17/§18).
#    Ici on definit une amplitude LOCALE = Phi_rey / [ (Mc/rho0) ] pour tester Romps.
Mc_over_rho_h = Mc_up_h / rho0
Mc_over_rho_s = Mc_up_s / rho0

# rapport local Phi_rey / (Mc/rho0)  -> doit etre ~ constant * Du si Romps tient
ratio_h = np.where(np.abs(Mc_over_rho_h) > 1e-6,
                   flux_glob_h / (Mc_over_rho_h + 1e-30), np.nan)

# 2) regression directe : flux_glob_h ~ k * (Mc/rho0) * Du   (Romps complet)
X = (Mc_over_rho_h * duc_h_loc)[sl_fit]
Y = flux_glob_h[sl_fit]
ok = np.isfinite(X) & np.isfinite(Y)
k_romps = (X[ok] @ Y[ok]) / (X[ok] @ X[ok]) if (X[ok] @ X[ok]) != 0 else np.nan
r_romps = np.corrcoef(X[ok], Y[ok])[0,1] if ok.sum() > 2 else np.nan
print(f'Romps local : Phi_rey ≈ k·(Mc/rho0)·Du   k={k_romps:+.3f}  R2={r_romps**2:.3f}')

# 3) Romps SANS le contraste : Phi_rey ~ k' * (Mc/rho0)   (test de robustesse)
X2 = Mc_over_rho_h[sl_fit]
k2 = (X2[ok] @ Y[ok]) / (X2[ok] @ X2[ok]) if (X2[ok] @ X2[ok]) != 0 else np.nan
r2_simple = np.corrcoef(X2[ok], Y[ok])[0,1] if ok.sum() > 2 else np.nan
print(f"Romps simplifie : Phi_rey ≈ k'·(Mc/rho0)        k'={k2:+.4f}  R2={r2_simple**2:.3f}")

fig, axes = plt.subplots(1, 2, figsize=(16, 7), sharey=True)

ax = axes[0]
ax.plot(flux_glob_h[sl_fit]*sc, zf, color='royalblue', lw=2.5, label="Φ_rey = ρ₀⟨u'w'⟩")
ax.plot((k_romps*Mc_over_rho_h*duc_h_loc)[sl_fit]*sc, zf, color='red', lw=2, ls='--',
        label='k·(Mc/ρ₀)·Du')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel('flux  (×10⁻³)'); ax.set_ylabel('Altitude (m)')
ax.set_title(f'Romps complet (R²={r_romps**2:.2f})', fontweight='bold')
ax.legend(fontsize=9); ax.grid(alpha=0.3)

ax = axes[1]
ax.plot(flux_glob_h[sl_fit]*sc, zf, color='royalblue', lw=2.5, label='Φ_rey')
ax.plot((k2*Mc_over_rho_h)[sl_fit]*sc, zf, color='green', lw=2, ls='--',
        label="k'·(Mc/ρ₀)")
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel('flux  (×10⁻³)')
ax.set_title(f'Romps simplifié (R²={r2_simple**2:.2f})', fontweight='bold')
ax.legend(fontsize=9); ax.grid(alpha=0.3)

plt.suptitle('S31 — Test Romps (2014) : flux de Reynolds vs flux de masse convectif',
             fontsize=13, fontweight='bold')
plt.tight_layout(); plt.show()
# Out:
# Romps local : Phi_rey ≈ k·(Mc/rho0)·Du   k=+1.153  R2=0.478
# Romps simplifie : Phi_rey ≈ k'·(Mc/rho0)        k'=-0.4557  R2=0.178

# %%
# ============================================================================
# S32 — Variables grande-echelle pour la parametrisation (predicteurs GCM)
#   - M_int      : flux de masse convectif integre sur la colonne (kg/m/s)
#   - shear      : cisaillement de vent grande-echelle |du_bar/dz| moyen
#   - cape_proxy : energie de flottabilite (proxy via theta_v, si dispo) sinon w'^2
#   On les calcule par region humide pour relier a l'amplitude du flux.
# ============================================================================

# 1) flux de masse integre (proxy de l'intensite convective)
M_int_h = np.trapz(Mc_up_h[sl_fit], zf)        # kg m-1 s-1
M_int_s = np.trapz(Mc_up_s[sl_fit], zf)
print(f'M integre humide = {M_int_h:.3f} kg/m/s   sec = {M_int_s:.3f}')

# 2) vent moyen de region et cisaillement
ubar_h_prof = np.zeros(n_z)
ds_u = xr.open_dataset(path3d('ua'))
for iz in range(n_z):
    acc = 0.0; n = 0
    for it in range(t_stat, n_t):
        acc += ds_u['ua'].isel({dim_t: it, dim_z: iz}).values[mh].mean()
        n += 1
    ubar_h_prof[iz] = acc / n
    gc.collect()
ds_u.close(); del ds_u; gc.collect()

dudz_h = np.gradient(ubar_h_prof, alt)
shear_h = np.nanmean(np.abs(dudz_h[sl_fit]))     # cisaillement moyen (s-1)
print(f'cisaillement moyen <|du/dz|> humide = {shear_h*1e3:.4f} x1e-3 s-1')

# 3) proxy CAPE via variance de w (energie cinetique verticale convective)
#    sqrt(<w'^2>) ~ vitesse convective w* liee a CAPE par w* ~ sqrt(2 CAPE)
w_star_h = np.zeros(n_z)
ds_w = xr.open_dataset(path3d('wa'))
for iz in range(n_z):
    acc = 0.0; n = 0
    for it in range(t_stat, n_t):
        w_r = ds_w['wa'].isel({dim_t: it, dim_z: iz}).values[mh]
        acc += (w_r**2).mean(); n += 1
        del w_r
    w_star_h[iz] = np.sqrt(acc / n)
    gc.collect()
ds_w.close(); del ds_w; gc.collect()

cape_proxy_h = 0.5 * np.nanmax(w_star_h[sl_fit])**2   # ~ CAPE (J/kg)
print(f'proxy CAPE humide ~ {cape_proxy_h:.1f} J/kg  (w* max={np.nanmax(w_star_h[sl_fit]):.2f} m/s)')

fig, axes = plt.subplots(1, 3, figsize=(15, 7), sharey=True)
for ax, prof, lab, col in [
    (axes[0], Mc_up_h[sl_fit]*scM, r'$M_c$ (×10⁻³ kg/m²/s)', 'royalblue'),
    (axes[1], dudz_h[sl_fit]*1e3,  r'$\partial_z\bar u$ (×10⁻³ s⁻¹)', 'crimson'),
    (axes[2], w_star_h[sl_fit],    r'$w_*=\sqrt{\langle w^2\rangle}$ (m/s)', 'seagreen')]:
    ax.plot(prof, zf, color=col, lw=2.5)
    ax.axvline(0, color='grey', alpha=0.4); ax.grid(alpha=0.3)
    ax.set_xlabel(lab)
axes[0].set_ylabel('Altitude (m)')
plt.suptitle('S32 — Prédicteurs grande-échelle (région humide)', fontsize=13, fontweight='bold')
plt.tight_layout(); plt.show()
# Out:
# M integre humide = 244.800 kg/m/s   sec = 96.222
# cisaillement moyen <|du/dz|> humide = 0.5091 x1e-3 s-1
# proxy CAPE humide ~ 0.1 J/kg  (w* max=0.37 m/s)

# %%
# ============================================================================
# S33 — Closure predictive flux de masse  ->  tendance du vent
#   Modele GCM-able :  Phi_param(z) = k * (Mc/rho0) * Du
#                      d_t ubar = -(1/rho0) d/dz( rho0 * Phi_param )
#   On confronte a la VERITE Reynolds  d_t ubar = -(1/rho0) d/dz( rho0 <u'w'> ).
#   k = k_romps (calibre en S31).  Aucune info Reynolds dans la prediction.
# ============================================================================

sl = slice(iz_lo, iz_top+1)
zf = alt[sl].astype(float)
st = 1e5  # m/s2 -> 1e-5

# flux parametrise (NE connait QUE Mc, rho0, Du, k)
Phi_param_h = k_romps * (Mc_up_h / rho0) * duc_h_loc        # equivaut a <u'w'> predit
# tendance predite  (on remet rho0 car flux_glob = rho0 <u'w'>)
tend_param_h = -np.gradient(rho0 * Phi_param_h, alt) / rho0
# verite
tend_rey_h   = -np.gradient(flux_glob_h, alt) / rho0

a = tend_rey_h[sl]; b = tend_param_h[sl]
ok = np.isfinite(a) & np.isfinite(b)
corr = np.corrcoef(a[ok], b[ok])[0,1]
rms  = np.sqrt(np.mean((a[ok]-b[ok])**2))
skill = 1 - np.sum((a[ok]-b[ok])**2)/np.sum((a[ok]-np.mean(a[ok]))**2)  # Nash-Sutcliffe
print(f'Closure flux de masse :  corr={corr:+.3f}  RMS={rms*st:.3f} x1e-5  skill(NSE)={skill:+.3f}')

fig, axes = plt.subplots(1, 2, figsize=(13, 8), sharey=True)

ax = axes[0]
ax.plot(flux_glob_h[sl]*sc, zf, color='royalblue', lw=2.5, label="Φ_rey (vérité)")
ax.plot((rho0*Phi_param_h)[sl]*sc, zf, color='red', lw=2, ls='--', label='Φ_param = k·Mc·Du')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel('ρ₀⟨u\'w\'⟩  (×10⁻³)'); ax.set_ylabel('Altitude (m)')
ax.set_title('Flux : vérité vs paramétré', fontweight='bold')
ax.legend(fontsize=9); ax.grid(alpha=0.3)

ax = axes[1]
ax.plot(a[ok]*st, zf[ok], color='royalblue', lw=2.5, label='Reynolds (vérité)')
ax.plot(b[ok]*st, zf[ok], color='red', lw=2, ls='--', label='closure flux de masse')
ax.axvline(0, color='grey', alpha=0.4)
ax.set_xlabel(r'$\partial_t\bar u$  (×10⁻⁵ m/s²)')
ax.set_title(f'Tendance du vent (NSE={skill:.2f})', fontweight='bold')
ax.legend(fontsize=9); ax.grid(alpha=0.3)

plt.suptitle('S33 — Closure CMT par flux de masse seul : prédiction de la force convective',
             fontsize=13, fontweight='bold')
plt.tight_layout(); plt.show()
# Out:
# Closure flux de masse :  corr=+0.359  RMS=0.713 x1e-5  skill(NSE)=-0.249

# %%
# ============================================================================
# S35 — Dependance en longueur d'onde (Romps 2014, eqs. 9-10)
#   tau(lambda) = (rho/M) (eps^2+m^2)/(eps m^2)   [temps d'amortissement]
#   w(lambda)   = -(M/rho) m^2/(eps^2+m^2)        [vitesse de descente]
#   avec m = 2pi/lambda.  Puis decomposition de Fourier verticale du vent moyen
#   pour verifier "petites lambda -> amorties plus vite".
# ============================================================================

sl   = slice(iz_lo, iz_top+1)
zf   = alt[sl].astype(float)
SDAY = 86400.0   # s -> jour

# ---- 1) parametres effectifs moyens sur la couche convective (humide) ----
M_over_rho = np.nanmean((Mc_up_h / rho0)[sl])        # m/s  (≈ 1 cm/s attendu)
# eps : on reprend celui de S30 s'il existe, sinon valeur de reference vent 1.5/km
try:
    eps_eff = abs(eps_glob_h)                         # s'il a ete calcule (m^-1)
    if not np.isfinite(eps_eff) or eps_eff == 0:
        raise ValueError
except (NameError, ValueError):
    eps_eff = 1.5e-3                                  # m^-1 (ref Romps vent)
print(f'M/rho effectif (humide, couche conv.) = {M_over_rho*100:.2f} cm/s')
print(f'eps effectif utilise                  = {eps_eff*1000:.2f} km-1')

# ---- 2) tau(lambda) et w(lambda) analytiques (eqs 9-10) ------------------
lam  = np.linspace(2000., 12000., 200)               # 2 - 12 km
m    = 2*np.pi/lam
tau  = (1.0/(M_over_rho)) * (eps_eff**2 + m**2)/(eps_eff*m**2)   # s
wdes = (M_over_rho)       *  m**2/(eps_eff**2 + m**2)            # m/s (|w|)
tau_day = tau/SDAY

# repere : limites petites/grandes longueurs d'onde
tau_small = 1.0/(M_over_rho*eps_eff)/SDAY             # lambda << 2pi/eps : tau ~ rho/(M eps)
print(f'tau (petite lambda, ~rho/M eps) = {tau_small:.2f} jour  (ref Romps 1 jour)')
print(f'tau a lambda=2 km  = {tau_day[0]:.2f} j   |  lambda=10 km = '
      f'{np.interp(10000,lam,tau_day):.2f} j   (fourchette attendue 1-10 j)')

# ---- 3) decomposition de Fourier verticale du vent moyen (humide) --------
#   On projette ubar(z) sur sin(m z) pour mesurer l'energie par longueur d'onde.
u_prof = ubar_h_prof[sl] - np.nanmean(ubar_h_prof[sl])   # on enleve la moyenne
z0     = zf - zf[0]
Lz     = z0[-1] - z0[0]
lam_k  = np.array([2*Lz/k for k in range(1, 9)])         # modes sin: lambda=2Lz/k
amp_k  = np.array([
    2.0/len(z0) * np.nansum(u_prof*np.sin(np.pi*k*z0/Lz)) for k in range(1, 9)
])
power_k = amp_k**2
# temps d'amortissement theorique de chaque mode present dans le vent
m_k   = 2*np.pi/lam_k
tau_k = (1.0/M_over_rho)*(eps_eff**2 + m_k**2)/(eps_eff*m_k**2)/SDAY

# ---- 4) figures ----------------------------------------------------------
fig, axes = plt.subplots(1, 3, figsize=(16, 6))

ax = axes[0]
ax.plot(lam/1000, tau_day, color='royalblue', lw=2.5)
ax.axhspan(1, 10, color='green', alpha=0.12, label='1-10 j (Matsuno-Gill)')
ax.set_xlabel('longueur d\'onde lambda (km)')
ax.set_ylabel('tau (jours)')
ax.set_title('Temps d\'amortissement tau(lambda)', fontweight='bold')
ax.legend(fontsize=9); ax.grid(alpha=0.3)

ax = axes[1]
ax.plot(lam/1000, wdes*100, color='crimson', lw=2.5)
ax.axhline(M_over_rho*100, color='grey', ls='--', alpha=0.7,
           label=f'M/rho = {M_over_rho*100:.1f} cm/s (limite)')
ax.set_xlabel('longueur d\'onde lambda (km)')
ax.set_ylabel('|w| (cm/s)')
ax.set_title('Vitesse de descente |w|(lambda)', fontweight='bold')
ax.legend(fontsize=9); ax.grid(alpha=0.3)

ax = axes[2]
ax.bar(lam_k/1000, power_k/np.nansum(power_k), width=0.4,
       color='steelblue', alpha=0.8, label='énergie du vent')
ax2 = ax.twinx()
ax2.plot(lam_k/1000, tau_k, 'o-', color='darkorange', lw=2, label='tau du mode')
ax2.set_ylabel('tau (jours)', color='darkorange')
ax.set_xlabel('longueur d\'onde lambda (km)')
ax.set_ylabel('énergie spectrale (norm.)')
ax.set_title('Spectre du vent vs tau\n(modes courts = amortis plus vite)', fontweight='bold')
ax.legend(fontsize=8, loc='upper left'); ax.grid(alpha=0.3)

plt.suptitle('S35 — Dépendance en longueur d\'onde (Romps 2014) : tau, w, spectre vertical du vent',
             fontsize=12, fontweight='bold')
plt.tight_layout(); plt.show()

# ---- 5) bilan chiffre ----------------------------------------------------
print()
print('-- Modes verticaux presents dans ubar (humide) --')
for k in range(len(lam_k)):
    print(f'  lambda={lam_k[k]/1000:5.2f} km : energie={power_k[k]/np.nansum(power_k)*100:5.1f}%'
          f'  tau_theo={tau_k[k]:5.2f} j')
print()
print('Lecture : les modes courts (lambda faible) ont tau plus petit')
print('-> amortis plus vite par la convection, conforme a Romps (eqs 9-10).')
# Out:
# M/rho effectif (humide, couche conv.) = 3.39 cm/s
# eps effectif utilise                  = 0.32 km-1
# tau (petite lambda, ~rho/M eps) = 1.08 jour  (ref Romps 1 jour)
# tau a lambda=2 km  = 1.09 j   |  lambda=10 km = 1.35 j   (fourchette attendue 1-10 j)
# -- Modes verticaux presents dans ubar (humide) --
#   lambda=30.89 km : energie=  5.9%  tau_theo= 3.69 j
#   lambda=15.45 km : energie=  3.8%  tau_theo= 1.73 j
#   lambda=10.30 km : energie=  0.6%  tau_theo= 1.37 j
#   lambda= 7.72 km : energie=  6.5%  tau_theo= 1.24 j
#   lambda= 6.18 km : energie= 23.8%  tau_theo= 1.18 j
#   lambda= 5.15 km : energie= 33.5%  tau_theo= 1.15 j
#   lambda= 4.41 km : energie= 20.6%  tau_theo= 1.13 j
#   lambda= 3.86 km : energie=  5.3%  tau_theo= 1.12 j
#
# Lecture : les modes courts (lambda faible) ont tau plus petit
# -> amortis plus vite par la convection, conforme a Romps (eqs 9-10).
